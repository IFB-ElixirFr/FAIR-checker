# %%
import requests

STATUS_BIOPORTAL = requests.head("https://data.bioontology.org/").status_code
STATUS_OLS = requests.head("https://www.ebi.ac.uk/ols4/index").status_code
STATUS_LOV = requests.head(
    "https://lov.linkeddata.es/dataset/lov/sparql"
).status_code

print("BioPortal status:", STATUS_BIOPORTAL)
print("OLS status:", STATUS_OLS)
print("LOV status:", STATUS_LOV)
# Out:
# BioPortal status: 200
# OLS status: 200
# LOV status: 200
