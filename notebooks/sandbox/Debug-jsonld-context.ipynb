# %% [markdown]
# ## WorkflowHub

# %%
nt_orig = """
<file:///home/trosnet/fair-checker/#cosifer-inputs-outdir> <http://schema.org/name> "outdir" .
<https://workflowhub.eu/people/4> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person> .
<file:///home/trosnet/fair-checker/#cosifer-inputs-index_col> <http://purl.org/dc/terms/conformsTo> "https://bioschemas.org/profiles/FormalParameter/1.0-RELEASE/" .
<file:///home/trosnet/fair-checker/#cosifer-inputs-separator> <http://purl.org/dc/terms/conformsTo> "https://bioschemas.org/profiles/FormalParameter/1.0-RELEASE/" .
<file:///home/trosnet/fair-checker/#cosifer-inputs-separator> <http://schema.org/name> "separator" .
<https://workflowhub.eu/projects/35> <http://schema.org/name> "iPC: individualizedPaediatricCure" .
<file:///home/trosnet/fair-checker/#cosifer-inputs-gmt_filepath> <http://purl.org/dc/terms/conformsTo> "https://bioschemas.org/profiles/FormalParameter/1.0-RELEASE/" .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/input> <file:///home/trosnet/fair-checker/#cosifer-inputs-gmt_filepath> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/url> <https://workflowhub.eu/workflows/118?version=1> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/input> <file:///home/trosnet/fair-checker/#cosifer-inputs-data_matrix> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/input> <file:///home/trosnet/fair-checker/#cosifer-inputs-index_col> .
<file:///home/trosnet/fair-checker/#cosifer-inputs-separator> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/FormalParameter> .
<file:///home/trosnet/fair-checker/#cwl> <http://schema.org/name> "Common Workflow Language" .
<file:///home/trosnet/fair-checker/#cosifer-inputs-data_matrix> <http://schema.org/name> "data_matrix" .
<file:///home/trosnet/fair-checker/#cwl> <http://schema.org/url> <https://www.commonwl.org/> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/sdPublisher> <https://about.workflowhub.eu/> .
<file:///home/trosnet/fair-checker/#cosifer-inputs-index_col> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/FormalParameter> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/dateModified> "2022-04-11T09:26:51Z"^^<http://schema.org/Date> .
<file:///home/trosnet/fair-checker/#cosifer-inputs-samples_on_rows> <http://purl.org/dc/terms/conformsTo> "https://bioschemas.org/profiles/FormalParameter/1.0-RELEASE/" .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/creator> <https://workflowhub.eu/people/110> .
<https://workflowhub.eu/people/110> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/output> <file:///home/trosnet/fair-checker/#cosifer-outputs-resdir> .
<https://workflowhub.eu/projects/35> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/version> "1"^^<http://www.w3.org/2001/XMLSchema#integer> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/producer> <https://workflowhub.eu/projects/35> .
<file:///home/trosnet/fair-checker/#cosifer-inputs-outdir> <http://purl.org/dc/terms/conformsTo> "https://bioschemas.org/profiles/FormalParameter/1.0-RELEASE/" .
<file:///home/trosnet/fair-checker/#cosifer-inputs-data_matrix> <http://purl.org/dc/terms/conformsTo> "https://bioschemas.org/profiles/FormalParameter/1.0-RELEASE/" .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/name> "COSIFER" .
<file:///home/trosnet/fair-checker/#cosifer-outputs-resdir> <http://schema.org/name> "resdir" .
<file:///home/trosnet/fair-checker/#cosifer-inputs-gmt_filepath> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/FormalParameter> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/input> <file:///home/trosnet/fair-checker/#cosifer-inputs-samples_on_rows> .
<file:///home/trosnet/fair-checker/#cosifer-inputs-index_col> <http://schema.org/name> "index_col" .
<https://about.workflowhub.eu/> <http://schema.org/name> "WorkflowHub" .
<file:///home/trosnet/fair-checker/#cosifer-inputs-samples_on_rows> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/FormalParameter> .
<https://about.workflowhub.eu/> <http://schema.org/url> <https://about.workflowhub.eu/> .
<file:///home/trosnet/fair-checker/#cosifer-inputs-samples_on_rows> <http://schema.org/name> "samples_on_rows" .
<file:///home/trosnet/fair-checker/#cosifer-outputs-resdir> <http://purl.org/dc/terms/conformsTo> "https://bioschemas.org/profiles/FormalParameter/1.0-RELEASE/" .
<https://workflowhub.eu/people/110> <http://schema.org/name> "José Mª Fernández" .
<https://workflowhub.eu/people/4> <http://schema.org/name> "Laura Rodriguez-Navas" .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/programmingLanguage> <file:///home/trosnet/fair-checker/#cwl> .
<file:///home/trosnet/fair-checker/#cosifer-inputs-outdir> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/FormalParameter> .
<https://about.workflowhub.eu/> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization> .
<https://workflowhub.eu/workflows/118?version=1> <http://purl.org/dc/terms/conformsTo> "https://bioschemas.org/profiles/ComputationalWorkflow/1.0-RELEASE/" .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/input> <file:///home/trosnet/fair-checker/#cosifer-inputs-separator> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/dateCreated> "2021-05-05T15:50:31Z"^^<http://schema.org/Date> .
<file:///home/trosnet/fair-checker/#cosifer-inputs-gmt_filepath> <http://schema.org/name> "gmt_filepath" .
<file:///home/trosnet/fair-checker/#cwl> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/ComputerLanguage> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/image> <https://workflowhub.eu/workflows/138/diagram?version=1> .
<file:///home/trosnet/fair-checker/#cwl> <http://schema.org/identifier> <https://w3id.org/cwl/v1.0/> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/creator> <https://workflowhub.eu/people/4> .
<https://workflowhub.eu/workflows/118?version=1> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/ComputationalWorkflow> .
<file:///home/trosnet/fair-checker/#cosifer-inputs-data_matrix> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/FormalParameter> .
<https://workflowhub.eu/workflows/118?version=1> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/SoftwareSourceCode> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/input> <file:///home/trosnet/fair-checker/#cosifer-inputs-outdir> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/license> <https://opensource.org/licenses/Apache-2.0> .
<file:///home/trosnet/fair-checker/#cosifer-outputs-resdir> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/FormalParameter> .
<https://workflowhub.eu/projects/35> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Project> .
<file:///home/trosnet/fair-checker/#cwl> <http://schema.org/alternateName> "CWL" .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/keywords> "cosifer, cancer, pediatric, rna-seq" .
"""

nt_new = """
<https://workflowhub.eu/projects/35> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization> .
<https://workflowhub.eu/workflows/118?version=1> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/ComputationalWorkflow> .
<https://workflowhub.eu/workflows/118#cosifer-inputs-separator> <http://purl.org/dc/terms/conformsTo> "https://bioschemas.org/profiles/FormalParameter/1.0-RELEASE/" .
<https://workflowhub.eu/people/110> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person> .
<https://workflowhub.eu/workflows/118?version=1> <http://purl.org/dc/terms/conformsTo> "https://bioschemas.org/profiles/ComputationalWorkflow/1.0-RELEASE/" .
<https://workflowhub.eu/projects/35> <http://schema.org/name> "iPC: individualizedPaediatricCure" .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/creator> <https://workflowhub.eu/people/4> .
<https://workflowhub.eu/workflows/118#cosifer-inputs-separator> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/FormalParameter> .
<https://workflowhub.eu/workflows/118#cosifer-inputs-samples_on_rows> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/FormalParameter> .
<https://workflowhub.eu/workflows/118#cosifer-inputs-outdir> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/FormalParameter> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/name> "COSIFER" .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/creator> <https://workflowhub.eu/people/110> .
<https://workflowhub.eu/workflows/118#cosifer-inputs-index_col> <http://purl.org/dc/terms/conformsTo> "https://bioschemas.org/profiles/FormalParameter/1.0-RELEASE/" .
<https://about.workflowhub.eu/> <http://schema.org/name> "WorkflowHub" .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/input> <https://workflowhub.eu/workflows/118#cosifer-inputs-separator> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/input> <https://workflowhub.eu/workflows/118#cosifer-inputs-outdir> .
<https://workflowhub.eu/workflows/118#cosifer-outputs-resdir> <http://purl.org/dc/terms/conformsTo> "https://bioschemas.org/profiles/FormalParameter/1.0-RELEASE/" .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/url> <https://workflowhub.eu/workflows/118?version=1> .
<https://about.workflowhub.eu/> <http://schema.org/url> <https://about.workflowhub.eu/> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/input> <https://workflowhub.eu/workflows/118#cosifer-inputs-data_matrix> .
<https://workflowhub.eu/workflows/118#cosifer-outputs-resdir> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/FormalParameter> .
<https://workflowhub.eu/workflows/118#cwl> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/ComputerLanguage> .
<https://workflowhub.eu/workflows/118#cosifer-inputs-outdir> <http://schema.org/name> "outdir" .
<https://workflowhub.eu/workflows/118#cosifer-outputs-resdir> <http://schema.org/name> "resdir" .
<https://workflowhub.eu/people/110> <http://schema.org/name> "Jos\u00E9 M\u00AA Fern\u00E1ndez" .
<https://workflowhub.eu/workflows/118#cosifer-inputs-data_matrix> <http://purl.org/dc/terms/conformsTo> "https://bioschemas.org/profiles/FormalParameter/1.0-RELEASE/" .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/input> <https://workflowhub.eu/workflows/118#cosifer-inputs-gmt_filepath> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/output> <https://workflowhub.eu/workflows/118#cosifer-outputs-resdir> .
<https://workflowhub.eu/workflows/118#cosifer-inputs-index_col> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/FormalParameter> .
<https://workflowhub.eu/workflows/118#cwl> <http://schema.org/alternateName> "CWL" .
<https://workflowhub.eu/workflows/118#cwl> <http://schema.org/url> <https://www.commonwl.org/> .
<https://workflowhub.eu/people/4> <http://schema.org/name> "Laura Rodriguez-Navas" .
<https://workflowhub.eu/workflows/118#cosifer-inputs-gmt_filepath> <http://schema.org/name> "gmt_filepath" .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/input> <https://workflowhub.eu/workflows/118#cosifer-inputs-samples_on_rows> .
<https://workflowhub.eu/workflows/118#cosifer-inputs-gmt_filepath> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/FormalParameter> .
<https://workflowhub.eu/projects/35> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Project> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/keywords> "cosifer, cancer, pediatric, rna-seq" .
<https://workflowhub.eu/workflows/118#cwl> <http://schema.org/name> "Common Workflow Language" .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/programmingLanguage> <https://workflowhub.eu/workflows/118#cwl> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/input> <https://workflowhub.eu/workflows/118#cosifer-inputs-index_col> .
<https://workflowhub.eu/workflows/118#cosifer-inputs-samples_on_rows> <http://schema.org/name> "samples_on_rows" .
<https://workflowhub.eu/workflows/118#cosifer-inputs-separator> <http://schema.org/name> "separator" .
<https://workflowhub.eu/workflows/118#cosifer-inputs-gmt_filepath> <http://purl.org/dc/terms/conformsTo> "https://bioschemas.org/profiles/FormalParameter/1.0-RELEASE/" .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/version> "1"^^<http://www.w3.org/2001/XMLSchema#integer> .
<https://workflowhub.eu/workflows/118?version=1> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/SoftwareSourceCode> .
<https://workflowhub.eu/workflows/118#cosifer-inputs-data_matrix> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/FormalParameter> .
<https://workflowhub.eu/people/4> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person> .
<https://workflowhub.eu/workflows/118#cosifer-inputs-index_col> <http://schema.org/name> "index_col" .
<https://about.workflowhub.eu/> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/sdPublisher> <https://about.workflowhub.eu/> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/producer> <https://workflowhub.eu/projects/35> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/image> <https://workflowhub.eu/workflows/138/diagram?version=1> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/license> <https://opensource.org/licenses/Apache-2.0> .
<https://workflowhub.eu/workflows/118#cosifer-inputs-outdir> <http://purl.org/dc/terms/conformsTo> "https://bioschemas.org/profiles/FormalParameter/1.0-RELEASE/" .
<https://workflowhub.eu/workflows/118#cosifer-inputs-samples_on_rows> <http://purl.org/dc/terms/conformsTo> "https://bioschemas.org/profiles/FormalParameter/1.0-RELEASE/" .
<https://workflowhub.eu/workflows/118#cwl> <http://schema.org/identifier> <https://w3id.org/cwl/v1.0/> .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/dateModified> "2022-04-11T09:26:51Z"^^<http://schema.org/Date> .
<https://workflowhub.eu/workflows/118#cosifer-inputs-data_matrix> <http://schema.org/name> "data_matrix" .
<https://workflowhub.eu/workflows/118?version=1> <http://schema.org/dateCreated> "2021-05-05T15:50:31Z"^^<http://schema.org/Date> .
"""

# %%
from rdflib import ConjunctiveGraph

G1 = ConjunctiveGraph()
G1.parse(data=nt_orig, format="nt")

G2 = ConjunctiveGraph()
G2.parse(data=nt_new, format="nt")
# Out:
# <Graph identifier=N33f9b2ab2a3e4df0acfa82c09c69cb9d (<class 'rdflib.graph.Graph'>)>

# %%
G3 = G1 - G2

# %%
print(len(G1))
print(len(G2))
print(len(G3))
# Out:
# 59
# 59
# 34

# %%
print(G3.serialize(format="nt"))
# Out:
# <file:///home/trosnet/fair-checker/#cosifer-inputs-index_col> <http://purl.org/dc/terms/conformsTo> "https://bioschemas.org/profiles/FormalParameter/1.0-RELEASE/" .
# <file:///home/trosnet/fair-checker/#cosifer-outputs-resdir> <http://purl.org/dc/terms/conformsTo> "https://bioschemas.org/profiles/FormalParameter/1.0-RELEASE/" .
# <file:///home/trosnet/fair-checker/#cosifer-outputs-resdir> <http://schema.org/name> "resdir" .
# <file:///home/trosnet/fair-checker/#cosifer-inputs-separator> <http://purl.org/dc/terms/conformsTo> "https://bioschemas.org/profiles/FormalParameter/1.0-RELEASE/" .
# <file:///home/trosnet/fair-checker/#cwl> <http://schema.org/identifier> <https://w3id.org/cwl/v1.0/> .
# <file:///home/trosnet/fair-checker/#cosifer-inputs-data_matrix> <http://schema.org/name> "data_matrix" .
# <file:///home/trosnet/fair-checker/#cosifer-inputs-gmt_filepath> <http://schema.org/name> "gmt_filepath" .
# ...

# %% [markdown]
# ## Bio.Tools

# %%
nt_orig = """
<https://bio.tools/jaspar/op_1/in_6> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://bioschemas.org/types/FormalParameter> .
<https://bio.tools/jaspar/op_1/in_1> <http://schema.org/identifier> "http://edamontology.org/data_1119" .
<https://bio.tools/jaspar> <http://bioschemas.org/input> <https://bio.tools/jaspar/op_1/in_6> .
<https://bio.tools/jaspar/op_1/in_1> <http://schema.org/sameAs> "http://edamontology.org/data_2755" .
<https://bio.tools/jaspar> <https://bio.tools/ontology/primaryContact> "Boris Lenhard" .
<https://bio.tools/jaspar> <http://bioschemas.org/input> <https://bio.tools/jaspar/op_1/in_3> .
<https://bio.tools/jaspar> <http://schema.org/citation> <https://doi.org/10.1093/bioinformatics/btx804> .
<https://bio.tools/jaspar/op_1/in_7> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://bioschemas.org/types/FormalParameter> .
<https://bio.tools/jaspar/op_2/in_2> <http://schema.org/sameAs> "http://edamontology.org/data_1119" .
<https://bio.tools/jaspar/op_1/in_4> <http://schema.org/identifier> "http://edamontology.org/data_2732" .
<https://bio.tools/jaspar> <http://schema.org/citation> "pubmed:29253085" .
<https://doi.org/10.1093/nar/gkp950> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork> .
<https://doi.org/10.1093/nar/gkv1176> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork> .
<https://bio.tools/jaspar/op_1/in_2> <http://schema.org/identifier> "http://edamontology.org/data_1077" .
<https://doi.org/10.1093/nar/gkj115> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork> .
<https://bio.tools/jaspar/op_2/in_2> <http://schema.org/identifier> "http://edamontology.org/data_1119" .
<https://doi.org/10.1093/nar/gkm955> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork> .
<https://bio.tools/jaspar/op_1/in_6> <http://schema.org/identifier> "http://edamontology.org/data_2291" .
<https://bio.tools/jaspar> <http://schema.org/citation> <https://doi.org/10.1093/nar/gkp950> .
<https://bio.tools/jaspar> <http://schema.org/applicationSubCategory> <http://edamontology.org/topic_0621> .
<https://bio.tools/jaspar> <http://schema.org/applicationSubCategory> <http://edamontology.org/topic_0780> .
<https://bio.tools/jaspar/op_1/in_1> <http://schema.org/identifier> "http://edamontology.org/data_2755" .
<https://bio.tools/jaspar> <http://schema.org/applicationSubCategory> <http://edamontology.org/topic_0622> .
<file:///home/trosnet/fair-checker/> <http://ogp.me/ns#image> "{{ngMeta['og:image']}}" .
<https://bio.tools/jaspar> <http://schema.org/citation> <https://doi.org/10.1093/nar/gkx1126> .
<https://doi.org/10.1093/nar/gkh012> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork> .
<https://bio.tools/jaspar> <https://bio.tools/ontology/primaryContact> <http://orcid.org/0000-0001-5127-5459> .
<https://bio.tools/jaspar> <http://schema.org/citation> "pubmed:14681366" .
<https://bio.tools/jaspar> <http://bioschemas.org/input> <https://bio.tools/jaspar/op_2/in_1> .
<https://bio.tools/jaspar/op_1/in_7> <http://schema.org/sameAs> "http://edamontology.org/data_3671" .
<https://bio.tools/jaspar/op_2/in_1> <http://schema.org/sameAs> "http://edamontology.org/data_3494" .
<https://bio.tools/jaspar> <http://schema.org/applicationSubCategory> <http://edamontology.org/topic_2815> .
<https://bio.tools/jaspar> <http://schema.org/isAccessibleForFree> "true"^^<http://www.w3.org/2001/XMLSchema#boolean> .
<https://bio.tools/jaspar> <http://schema.org/softwareHelp> <http://jaspar.genereg.net/faq/> .
<https://bio.tools/jaspar/op_1/in_1> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://bioschemas.org/types/FormalParameter> .
<https://bio.tools/jaspar> <http://schema.org/citation> "pubmed:19906716" .
<https://bio.tools/jaspar/op_1/in_1> <http://schema.org/sameAs> "http://edamontology.org/data_1119" .
<https://bio.tools/jaspar> <http://bioschemas.org/output> <https://bio.tools/jaspar/op_2/in_1> .
<https://bio.tools/jaspar> <http://schema.org/applicationSubCategory> <http://edamontology.org/topic_0204> .
<https://bio.tools/jaspar> <http://schema.org/citation> <https://doi.org/10.1093/nar/gkh012> .
<https://bio.tools/jaspar/op_1/in_4> <http://schema.org/sameAs> "http://edamontology.org/data_2732" .
<https://bio.tools/jaspar> <http://schema.org/citation> <https://doi.org/10.1093/nar/gkm955> .
<https://bio.tools/jaspar/op_1/in_6> <http://schema.org/name> "UniProt ID" .
<https://bio.tools/jaspar/op_1/in_6> <http://schema.org/sameAs> "http://edamontology.org/data_2291" .
<https://bio.tools/jaspar> <http://bioschemas.org/input> <https://bio.tools/jaspar/op_1/in_5> .
<https://bio.tools/jaspar/op_1/in_4> <http://schema.org/name> "Family name" .
<https://bio.tools/jaspar> <https://bio.tools/ontology/primaryContact> "Albin Sandelin" .
<https://bio.tools/jaspar/op_1/in_4> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://bioschemas.org/types/FormalParameter> .
<https://bio.tools/jaspar> <https://bio.tools/ontology/primaryContact> "Wyeth Wasserman" .
<https://bio.tools/jaspar/op_1/in_5> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://bioschemas.org/types/FormalParameter> .
<https://bio.tools/jaspar> <http://bioschemas.org/input> <https://bio.tools/jaspar/op_1/in_7> .
<https://bio.tools/jaspar> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/SoftwareApplication> .
<https://bio.tools/jaspar> <http://purl.org/dc/terms/conformsTo> "https://bioschemas.org/profiles/ComputationalTool/1.0-RELEASE" .
<https://bio.tools/jaspar/op_2/in_2> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://bioschemas.org/types/FormalParameter> .
<https://bio.tools/jaspar/op_1/in_3> <http://schema.org/sameAs> "http://edamontology.org/data_1868" .
<https://bio.tools/jaspar> <http://schema.org/softwareHelp> <http://jaspar.genereg.net/docs/> .
<file:///home/trosnet/fair-checker/> <http://ogp.me/ns#description> "{{ngMeta['og:description']}}" .
<https://bio.tools/jaspar/op_1/in_5> <http://schema.org/sameAs> "http://edamontology.org/data_1045" .
<https://bio.tools/jaspar> <http://schema.org/softwareHelp> <http://jaspar.genereg.net/api/v1/docs/> .
<https://bio.tools/jaspar/op_1/in_3> <http://schema.org/name> "Taxon" .
<https://bio.tools/jaspar> <http://schema.org/citation> "pubmed:26531826" .
<file:///home/trosnet/fair-checker/> <http://ogp.me/ns#title> "{{ngMeta['og:title']}}" .
<https://bio.tools/jaspar/op_1/in_3> <http://schema.org/identifier> "http://edamontology.org/data_1868" .
<https://bio.tools/jaspar/op_2/in_1> <http://schema.org/name> "JASPAR profile ID" .
<https://doi.org/10.1093/nar/gkx1126> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork> .
<http://orcid.org/0000-0001-5127-5459> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <schema:Person> .
<https://bio.tools/jaspar> <http://bioschemas.org/input> <https://bio.tools/jaspar/op_1/in_2> .
<https://bio.tools/jaspar> <http://bioschemas.org/input> <https://bio.tools/jaspar/op_1/in_1> .
<https://bio.tools/jaspar/op_1/in_5> <http://schema.org/identifier> "http://edamontology.org/data_1045" .
<https://bio.tools/jaspar> <http://schema.org/citation> <https://doi.org/10.1093/nar/gkt997> .
<https://bio.tools/jaspar/op_1/in_1> <http://schema.org/name> "JASPAR profile ID" .
<https://bio.tools/jaspar> <http://schema.org/citation> "pubmed:18006571" .
<https://bio.tools/jaspar/op_2/in_1> <http://schema.org/sameAs> "http://edamontology.org/data_1119" .
<https://bio.tools/jaspar> <http://schema.org/citation> <https://doi.org/10.1093/nar/gkv1176> .
<https://bio.tools/jaspar/op_1/in_5> <http://schema.org/name> "Species name" .
<https://bio.tools/jaspar/op_1/in_2> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://bioschemas.org/types/FormalParameter> .
<https://bio.tools/jaspar> <http://schema.org/citation> "pubmed:24194598" .
<https://bio.tools/jaspar> <http://schema.org/featureList> <http://edamontology.org/operation_0445> .
<https://bio.tools/jaspar> <http://bioschemas.org/input> <https://bio.tools/jaspar/op_1/in_4> .
<https://bio.tools/jaspar> <http://bioschemas.org/input> <https://bio.tools/jaspar/op_2/in_2> .
<https://bio.tools/jaspar/op_2/in_1> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://bioschemas.org/types/FormalParameter> .
<https://bio.tools/jaspar> <http://bioschemas.org/output> <https://bio.tools/jaspar/op_1/in_1> .
<https://bio.tools/jaspar> <http://schema.org/applicationSubCategory> <http://edamontology.org/topic_0749> .
<https://bio.tools/jaspar/op_2/in_1> <http://schema.org/name> "DNA sequence" .
<https://bio.tools/jaspar/op_1/in_1> <http://schema.org/name> "Transcription factor name" .
<https://bio.tools/jaspar/op_2/in_2> <http://schema.org/name> "JASPAR profile ID" .
<https://bio.tools/jaspar/op_1/in_7> <http://schema.org/name> "Text" .
<https://bio.tools/jaspar> <http://schema.org/featureList> <http://edamontology.org/operation_2421> .
<https://bio.tools/jaspar> <http://schema.org/citation> <https://doi.org/10.1093/nar/gkj115> .
<https://doi.org/10.1093/nar/gkt997> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork> .
<https://bio.tools/jaspar/op_1/in_3> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://bioschemas.org/types/FormalParameter> .
<https://bio.tools/jaspar/op_1/in_2> <http://schema.org/name> "Transcription factor identifier" .
<https://bio.tools/jaspar> <http://schema.org/citation> "pubmed:16381983" .
<https://bio.tools/jaspar/op_1/in_7> <http://schema.org/identifier> "http://edamontology.org/data_3671" .
<https://bio.tools/jaspar/op_2/in_1> <http://schema.org/identifier> "http://edamontology.org/data_3494" .
<https://bio.tools/jaspar/op_1/in_2> <http://schema.org/sameAs> "http://edamontology.org/data_1077" .
<https://doi.org/10.1093/bioinformatics/btx804> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork> .
<https://bio.tools/jaspar/op_2/in_1> <http://schema.org/identifier> "http://edamontology.org/data_1119" .
"""

nt_new = """
<https://bio.tools/jaspar> <http://schema.org/citation> <https://doi.org/10.1093/nar/gkx1126> .
<https://doi.org/10.1093/nar/gkj115> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork> .
<https://bio.tools/jaspar/op_1/in_7> <http://schema.org/sameAs> "http://edamontology.org/data_3671" .
<https://doi.org/10.1093/nar/gkx1126> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork> .
<https://bio.tools/jaspar> <http://bioschemas.org/input> <https://bio.tools/jaspar/op_1/in_3> .
<https://bio.tools/jaspar> <http://schema.org/applicationSubCategory> <http://edamontology.org/topic_0749> .
<https://bio.tools/jaspar/op_1/in_1> <http://schema.org/name> "JASPAR profile ID" .
<https://bio.tools/jaspar> <http://schema.org/citation> <https://doi.org/10.1093/nar/gkv1176> .
<https://bio.tools/jaspar/op_1/in_1> <http://schema.org/sameAs> "http://edamontology.org/data_2755" .
<https://bio.tools/jaspar/op_2/in_1> <http://schema.org/name> "JASPAR profile ID" .
<https://bio.tools/jaspar/op_1/in_3> <http://schema.org/name> "Taxon" .
<https://bio.tools/jaspar> <http://schema.org/citation> "pubmed:16381983" .
<https://bio.tools/jaspar/op_1/in_3> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://bioschemas.org/types/FormalParameter> .
<https://bio.tools/jaspar> <http://schema.org/citation> "pubmed:14681366" .
<https://bio.tools/jaspar/op_1/in_7> <http://schema.org/name> "Text" .
<https://bio.tools/jaspar> <https://bio.tools/ontology/primaryContact> <http://orcid.org/0000-0001-5127-5459> .
<https://bio.tools/jaspar> <http://bioschemas.org/input> <https://bio.tools/jaspar/op_1/in_2> .
<https://bio.tools/jaspar> <http://purl.org/dc/terms/conformsTo> "https://bioschemas.org/profiles/ComputationalTool/1.0-RELEASE" .
<https://bio.tools/jaspar> <http://bioschemas.org/input> <https://bio.tools/jaspar/op_1/in_4> .
<https://doi.org/10.1093/nar/gkv1176> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork> .
<https://bio.tools/jaspar> <http://bioschemas.org/input> <https://bio.tools/jaspar/op_1/in_5> .
<https://doi.org/10.1093/nar/gkm955> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork> .
<https://bio.tools/jaspar> <http://schema.org/citation> "pubmed:26531826" .
<https://bio.tools/jaspar> <http://schema.org/applicationSubCategory> <http://edamontology.org/topic_0621> .
<https://bio.tools/jaspar/op_1/in_2> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://bioschemas.org/types/FormalParameter> .
<https://bio.tools/jaspar> <http://bioschemas.org/input> <https://bio.tools/jaspar/op_2/in_1> .
<https://bio.tools/jaspar> <http://schema.org/citation> <https://doi.org/10.1093/nar/gkm955> .
<https://bio.tools/jaspar> <http://schema.org/citation> "pubmed:24194598" .
<https://doi.org/10.1093/bioinformatics/btx804> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork> .
<https://bio.tools/jaspar> <http://bioschemas.org/output> <https://bio.tools/jaspar/op_1/in_1> .
<https://bio.tools/jaspar/op_2/in_2> <http://schema.org/identifier> "http://edamontology.org/data_1119" .
<https://bio.tools/jaspar> <http://schema.org/applicationSubCategory> <http://edamontology.org/topic_0780> .
<https://bio.tools/jaspar/op_2/in_1> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://bioschemas.org/types/FormalParameter> .
<https://bio.tools/jaspar> <http://bioschemas.org/input> <https://bio.tools/jaspar/op_2/in_2> .
<https://bio.tools/jaspar> <http://schema.org/citation> "pubmed:29253085" .
<https://bio.tools/jaspar> <http://bioschemas.org/input> <https://bio.tools/jaspar/op_1/in_1> .
<https://bio.tools/jaspar> <http://schema.org/citation> <https://doi.org/10.1093/nar/gkp950> .
<https://bio.tools/jaspar/op_1/in_5> <http://schema.org/name> "Species name" .
<https://bio.tools/jaspar/op_2/in_1> <http://schema.org/sameAs> "http://edamontology.org/data_3494" .
<https://bio.tools/jaspar/op_1/in_5> <http://schema.org/identifier> "http://edamontology.org/data_1045" .
<https://bio.tools/jaspar> <http://bioschemas.org/input> <https://bio.tools/jaspar/op_1/in_7> .
<https://bio.tools/jaspar/op_1/in_6> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://bioschemas.org/types/FormalParameter> .
<https://bio.tools/jaspar/op_2/in_1> <http://schema.org/name> "DNA sequence" .
<http://bio.tools/jaspar> <http://ogp.me/ns#description> "{{ngMeta['og:description']}}" .
<https://doi.org/10.1093/nar/gkh012> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork> .
<https://bio.tools/jaspar/op_2/in_1> <http://schema.org/sameAs> "http://edamontology.org/data_1119" .
<https://bio.tools/jaspar> <http://schema.org/softwareHelp> <http://jaspar.genereg.net/docs/> .
<https://bio.tools/jaspar> <http://schema.org/citation> <https://doi.org/10.1093/bioinformatics/btx804> .
<https://bio.tools/jaspar/op_2/in_1> <http://schema.org/identifier> "http://edamontology.org/data_1119" .
<https://bio.tools/jaspar/op_1/in_4> <http://schema.org/sameAs> "http://edamontology.org/data_2732" .
<https://bio.tools/jaspar/op_1/in_6> <http://schema.org/identifier> "http://edamontology.org/data_2291" .
<https://bio.tools/jaspar/op_1/in_1> <http://schema.org/identifier> "http://edamontology.org/data_1119" .
<https://bio.tools/jaspar> <http://schema.org/applicationSubCategory> <http://edamontology.org/topic_2815> .
<https://bio.tools/jaspar/op_1/in_4> <http://schema.org/identifier> "http://edamontology.org/data_2732" .
<https://bio.tools/jaspar> <http://schema.org/featureList> <http://edamontology.org/operation_2421> .
<https://bio.tools/jaspar> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/SoftwareApplication> .
<https://bio.tools/jaspar/op_1/in_7> <http://schema.org/identifier> "http://edamontology.org/data_3671" .
<https://bio.tools/jaspar> <http://schema.org/applicationSubCategory> <http://edamontology.org/topic_0204> .
<https://bio.tools/jaspar> <http://schema.org/featureList> <http://edamontology.org/operation_0445> .
<https://bio.tools/jaspar/op_2/in_2> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://bioschemas.org/types/FormalParameter> .
<https://bio.tools/jaspar> <http://schema.org/isAccessibleForFree> "true"^^<http://www.w3.org/2001/XMLSchema#boolean> .
<https://bio.tools/jaspar> <http://bioschemas.org/output> <https://bio.tools/jaspar/op_2/in_1> .
<https://bio.tools/jaspar> <http://schema.org/citation> "pubmed:19906716" .
<https://bio.tools/jaspar> <http://schema.org/citation> <https://doi.org/10.1093/nar/gkt997> .
<https://bio.tools/jaspar/op_1/in_1> <http://schema.org/name> "Transcription factor name" .
<http://bio.tools/jaspar> <http://ogp.me/ns#image> "{{ngMeta['og:image']}}" .
<https://bio.tools/jaspar> <http://schema.org/citation> "pubmed:18006571" .
<https://bio.tools/jaspar/op_1/in_1> <http://schema.org/identifier> "http://edamontology.org/data_2755" .
<https://bio.tools/jaspar/op_1/in_2> <http://schema.org/sameAs> "http://edamontology.org/data_1077" .
<https://bio.tools/jaspar> <https://bio.tools/ontology/primaryContact> "Albin Sandelin" .
<https://bio.tools/jaspar> <http://bioschemas.org/input> <https://bio.tools/jaspar/op_1/in_6> .
<https://bio.tools/jaspar> <http://schema.org/softwareHelp> <http://jaspar.genereg.net/faq/> .
<https://bio.tools/jaspar> <https://bio.tools/ontology/primaryContact> "Boris Lenhard" .
<https://bio.tools/jaspar/op_1/in_2> <http://schema.org/identifier> "http://edamontology.org/data_1077" .
<https://bio.tools/jaspar> <http://schema.org/softwareHelp> <http://jaspar.genereg.net/api/v1/docs/> .
<https://bio.tools/jaspar/op_2/in_2> <http://schema.org/sameAs> "http://edamontology.org/data_1119" .
<http://bio.tools/jaspar> <http://ogp.me/ns#title> "{{ngMeta['og:title']}}" .
<https://bio.tools/jaspar/op_1/in_2> <http://schema.org/name> "Transcription factor identifier" .
<https://bio.tools/jaspar/op_1/in_3> <http://schema.org/sameAs> "http://edamontology.org/data_1868" .
<https://bio.tools/jaspar/op_1/in_3> <http://schema.org/identifier> "http://edamontology.org/data_1868" .
<https://bio.tools/jaspar> <http://schema.org/applicationSubCategory> <http://edamontology.org/topic_0622> .
<https://bio.tools/jaspar/op_2/in_2> <http://schema.org/name> "JASPAR profile ID" .
<https://bio.tools/jaspar/op_1/in_4> <http://schema.org/name> "Family name" .
<https://bio.tools/jaspar> <https://bio.tools/ontology/primaryContact> "Wyeth Wasserman" .
<https://bio.tools/jaspar> <http://schema.org/citation> <https://doi.org/10.1093/nar/gkh012> .
<https://bio.tools/jaspar/op_1/in_1> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://bioschemas.org/types/FormalParameter> .
<http://orcid.org/0000-0001-5127-5459> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <schema:Person> .
<https://bio.tools/jaspar/op_1/in_5> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://bioschemas.org/types/FormalParameter> .
<https://bio.tools/jaspar/op_1/in_5> <http://schema.org/sameAs> "http://edamontology.org/data_1045" .
<https://bio.tools/jaspar/op_1/in_6> <http://schema.org/name> "UniProt ID" .
<https://bio.tools/jaspar/op_1/in_7> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://bioschemas.org/types/FormalParameter> .
<https://bio.tools/jaspar/op_1/in_4> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://bioschemas.org/types/FormalParameter> .
<https://doi.org/10.1093/nar/gkp950> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork> .
<https://doi.org/10.1093/nar/gkt997> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork> .
<https://bio.tools/jaspar> <http://schema.org/citation> <https://doi.org/10.1093/nar/gkj115> .
<https://bio.tools/jaspar/op_1/in_6> <http://schema.org/sameAs> "http://edamontology.org/data_2291" .
<https://bio.tools/jaspar/op_1/in_1> <http://schema.org/sameAs> "http://edamontology.org/data_1119" .
<https://bio.tools/jaspar/op_2/in_1> <http://schema.org/identifier> "http://edamontology.org/data_3494" .
"""

G1 = ConjunctiveGraph()
G1.parse(data=nt_orig, format="nt")

G2 = ConjunctiveGraph()
G2.parse(data=nt_new, format="nt")

G3 = G1 - G2

# %%
print(len(G1))
print(len(G2))
print(len(G3))
# Out:
# 98
# 98
# 3

# %%
print(G3.serialize(format="nt"))
# Out:
# <file:///home/trosnet/fair-checker/> <http://ogp.me/ns#description> "{{ngMeta['og:description']}}" .
# <file:///home/trosnet/fair-checker/> <http://ogp.me/ns#title> "{{ngMeta['og:title']}}" .
# <file:///home/trosnet/fair-checker/> <http://ogp.me/ns#image> "{{ngMeta['og:image']}}" .

# %%
data_cite_orig = """
@prefix sc: <http://schema.org/> .

<https://doi.org/10.7892/boris.108387> a sc:ScholarlyArticle ;
    sc:author [ a sc:Person ;
            sc:familyName "Villiger" ;
            sc:givenName "Peter M" ;
            sc:name "Peter M Villiger" ],
        [ a sc:Person ;
            sc:familyName "Adler" ;
            sc:givenName "Sabine" ;
            sc:name "Sabine Adler" ],
        [ a sc:Person ;
            sc:familyName "Villiger" ;
            sc:givenName "Peter M" ;
            sc:name "Peter M Villiger" ],
        [ a sc:Person ;
            sc:familyName "Sprecher" ;
            sc:givenName "Marco" ;
            sc:name "Marco Sprecher" ],
        [ a sc:Person ;
            sc:familyName "Wermelinger" ;
            sc:givenName "Felix" ;
            sc:name "Felix Wermelinger" ],
        [ a sc:Person ;
            sc:familyName "Bonel" ;
            sc:givenName "Harald Marcel" ;
            sc:name "Harald Marcel Bonel" ],
        [ a sc:Person ;
            sc:familyName "Klink" ;
            sc:givenName "Thorsten" ;
            sc:name "Thorsten Klink" ],
        [ a sc:Person ;
            sc:familyName "Wermelinger" ;
            sc:givenName "Felix" ;
            sc:name "Felix Wermelinger" ],
        [ a sc:Person ;
            sc:familyName "Adler" ;
            sc:givenName "Sabine" ;
            sc:name "Sabine Adler" ],
        [ a sc:Person ;
            sc:familyName "Bonel" ;
            sc:givenName "Harald Marcel" ;
            sc:name "Harald Marcel Bonel" ],
        [ a sc:Person ;
            sc:familyName "Klink" ;
            sc:givenName "Thorsten" ;
            sc:name "Thorsten Klink" ],
        [ a sc:Person ;
            sc:familyName "Sprecher" ;
            sc:givenName "Marco" ;
            sc:name "Marco Sprecher" ] ;
    sc:datePublished "2017"^^sc:Date ;
    sc:description "OBJECTIVE To evaluate contrast-enhanced magnetic resonance angiography (MRA) in diagnosis of inflammatory aortic involvement in patients with clinical suspicion of large-vessel vasculitis. PATIENTS AND METHODS Seventy-five patients, mean age 62 years (range 16-82 years), 44 female and 31 male, underwent gadolinium-enhanced MRA and were evaluated retrospectively. Thoracic MRA was performed in 32 patients, abdominal MRA in 7 patients and both thoracic and abdominal MRA in 36 patients. Temporal arterial biopsies were obtained from 22/75 patients. MRA positivity was defined as increased aortic wall signal in late gadolinium-enhanced axial turbo inversion recovery magnitude (TIRM) series. The influence of prior glucocorticoid intake on MRA outcome was evaluated. RESULTS MRA was positive in 24/75 patients, with lesions located in the thorax in 7 patients, the abdomen in 5 and in both thorax and abdomen in 12. Probability for positive MRA after glucocorticoid intake for more than 5 days before MRA was reduced by 89.3%. Histology was negative in 3/10 MRA-positive patients and positive in 5/12 MRA-negative patients. All 5/12 histology positive / MRA-negative patients had glucocorticoids for &gt;5 days prior to MRA and were diagnosed as having vasculitis. Positive predictive value for MRA was 92%, negative predictive value was 88%. CONCLUSIONS Contrast-enhanced MRA reliably identifies large vessel vasculitis. Vasculitic signals in MRA are very sensitive to glucocorticoids, suggesting that MRA should be done before glucocorticoid treatment." ;
    sc:encodingFormat "application/pdf" ;
    sc:inLanguage "en" ;
    sc:keywords "610 Medicine &amp; health" ;
    sc:name "Diagnostic value of contrast-enhanced magnetic resonance angiography in large-vessel vasculitis." ;
    sc:provider [ a sc:Organization ;
            sc:name "datacite" ],
        [ a sc:Organization ;
            sc:name "datacite" ] ;
    sc:publisher [ a sc:Organization ;
            sc:name "EMH Schweizerischer Ärzteverlag" ],
        [ a sc:Organization ;
            sc:name "EMH Schweizerischer Ärzteverlag" ] ;
    sc:schemaVersion "http://datacite.org/schema/kernel-4" ;
    sc:url <https://boris.unibe.ch/108387/> .
"""

datacite_new = """
@prefix sc: <http://schema.org/> .

<https://doi.org/10.7892/boris.108387> a sc:ScholarlyArticle ;
    sc:author [ a sc:Person ;
            sc:familyName "Wermelinger" ;
            sc:givenName "Felix" ;
            sc:name "Felix Wermelinger" ],
        [ a sc:Person ;
            sc:familyName "Sprecher" ;
            sc:givenName "Marco" ;
            sc:name "Marco Sprecher" ],
        [ a sc:Person ;
            sc:familyName "Klink" ;
            sc:givenName "Thorsten" ;
            sc:name "Thorsten Klink" ],
        [ a sc:Person ;
            sc:familyName "Villiger" ;
            sc:givenName "Peter M" ;
            sc:name "Peter M Villiger" ],
        [ a sc:Person ;
            sc:familyName "Bonel" ;
            sc:givenName "Harald Marcel" ;
            sc:name "Harald Marcel Bonel" ],
        [ a sc:Person ;
            sc:familyName "Adler" ;
            sc:givenName "Sabine" ;
            sc:name "Sabine Adler" ] ;
    sc:datePublished "2017"^^sc:Date ;
    sc:description "OBJECTIVE To evaluate contrast-enhanced magnetic resonance angiography (MRA) in diagnosis of inflammatory aortic involvement in patients with clinical suspicion of large-vessel vasculitis. PATIENTS AND METHODS Seventy-five patients, mean age 62 years (range 16-82 years), 44 female and 31 male, underwent gadolinium-enhanced MRA and were evaluated retrospectively. Thoracic MRA was performed in 32 patients, abdominal MRA in 7 patients and both thoracic and abdominal MRA in 36 patients. Temporal arterial biopsies were obtained from 22/75 patients. MRA positivity was defined as increased aortic wall signal in late gadolinium-enhanced axial turbo inversion recovery magnitude (TIRM) series. The influence of prior glucocorticoid intake on MRA outcome was evaluated. RESULTS MRA was positive in 24/75 patients, with lesions located in the thorax in 7 patients, the abdomen in 5 and in both thorax and abdomen in 12. Probability for positive MRA after glucocorticoid intake for more than 5 days before MRA was reduced by 89.3%. Histology was negative in 3/10 MRA-positive patients and positive in 5/12 MRA-negative patients. All 5/12 histology positive / MRA-negative patients had glucocorticoids for &gt;5 days prior to MRA and were diagnosed as having vasculitis. Positive predictive value for MRA was 92%, negative predictive value was 88%. CONCLUSIONS Contrast-enhanced MRA reliably identifies large vessel vasculitis. Vasculitic signals in MRA are very sensitive to glucocorticoids, suggesting that MRA should be done before glucocorticoid treatment." ;
    sc:encodingFormat "application/pdf" ;
    sc:inLanguage "en" ;
    sc:keywords "610 Medicine &amp; health" ;
    sc:name "Diagnostic value of contrast-enhanced magnetic resonance angiography in large-vessel vasculitis." ;
    sc:provider [ a sc:Organization ;
            sc:name "datacite" ] ;
    sc:publisher [ a sc:Organization ;
            sc:name "EMH Schweizerischer Ärzteverlag" ] ;
    sc:schemaVersion "http://datacite.org/schema/kernel-4" ;
    sc:url <https://boris.unibe.ch/108387/> .
"""

# %%
G1 = ConjunctiveGraph()
G1.parse(data=data_cite_orig, format="turtle")

G2 = ConjunctiveGraph()
G2.parse(data=datacite_new, format="turtle")

G3 = G1 - G2

# %%
print(len(G1))
print(len(G2))
print(len(G3))
print(G3.serialize(format="nt"))
# Out:
# 81
# 45
# 72
# <https://doi.org/10.7892/boris.108387> <http://schema.org/provider> _:n63dc7cb167d04bd1ba8e86a3fb0d047cb14 .
# _:n63dc7cb167d04bd1ba8e86a3fb0d047cb1 <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person> .
# _:n63dc7cb167d04bd1ba8e86a3fb0d047cb2 <http://schema.org/givenName> "Sabine" .
# _:n63dc7cb167d04bd1ba8e86a3fb0d047cb2 <http://schema.org/familyName> "Adler" .
# <https://doi.org/10.7892/boris.108387> <http://schema.org/author> _:n63dc7cb167d04bd1ba8e86a3fb0d047cb2 .
# <https://doi.org/10.7892/boris.108387> <http://schema.org/author> _:n63dc7cb167d04bd1ba8e86a3fb0d047cb9 .
# _:n63dc7cb167d04bd1ba8e86a3fb0d047cb11 <http://schema.org/name> "Thorsten Klink" .
# _:n63dc7cb167d04bd1ba8e86a3fb0d047cb6 <http://schema.org/name> "Harald Marcel Bonel" .
# _:n63dc7cb167d04bd1ba8e86a3fb0d047cb12 <http://schema.org/givenName> "Marco" .
# _:n63dc7cb167d04bd1ba8e86a3fb0d047cb7 <http://schema.org/familyName> "Klink" .
# ...
