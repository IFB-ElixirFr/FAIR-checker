# %%
data = {
    "value": "\u003Chtml lang=\"en\" ng-app=\"elixir_front\" class=\"no-js ng-scope\">\u003C!--\u003C![endif]-->\u003Chead>\u003Cstyle type=\"text/css\">@charset \"UTF-8\";[ng\\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\\:form{display:block;}.ng-animate-shim{visibility:hidden;}.ng-anchor{position:absolute;}\u003C/style>\n\t\u003Cmeta charset=\"utf-8\">\n\t\u003Cbase href=\"/\">\n\t\u003Cmeta http-equiv=\"X-UA-Compatible\" content=\"IE=edge\">\n\t\u003Cmeta name=\"google-site-verification\" content=\"Vk6bfzjuRdI3ej15jMi0_wW1pUoduExCekkrNpO9u2U\">\n\t\u003Ctitle ng-bind=\"ngMeta.title\" class=\"ng-binding\">bio.tools\u003C/title>\n\t\u003Cmeta name=\"description\" content=\"\">\n\t\u003Cmeta property=\"og:title\" content=\"\">\n\t\u003Cmeta property=\"og:description\" content=\"\">\n\t\u003Cmeta property=\"og:image\" content=\"https://bio.tools/img/ELIXIR_logo_white_background_small.png\">\n    \u003Cmeta property=\"datePublished\" content=\"\">\n    \u003Cmeta property=\"article:published_time\" content=\"\">\n    \u003Cmeta property=\"dateModified\" content=\"\">\n    \u003Cmeta property=\"article:modified_time\" content=\"\">\n    \u003Cmeta property=\"og:updated_time\" content=\"\">\n\t\u003Cmeta name=\"fragment\" content=\"!\">\n\t\u003Cmeta name=\"viewport\" content=\"width=device-width, initial-scale=1.0\">\n\t\u003Clink href=\"https://fonts.googleapis.com/css?family=Open+Sans:300,400,700\" rel=\"stylesheet\" type=\"text/css\">\n\t\u003Clink href=\"https://fonts.googleapis.com/css?family=Roboto\" rel=\"stylesheet\">\n\t\u003Clink href=\"/dist/vendor.min.css\" rel=\"stylesheet\">\n\t\u003Clink href=\"/dist/app.min.css\" rel=\"stylesheet\">\n\t\u003Clink rel=\"icon\" type=\"image/png\" href=\"/img/favicon.ico\">\n\t\u003Cscript defer=\"\" data-domain=\"bio.tools\" src=\"https://plausible.galaxyproject.eu/js/script.js\">\u003C/script>\n\u003Cscript id=\"altmetric-embed-js\" src=\"https://embed.altmetric.com/assets/altmetric_badges-c21a2f91e3e5dbe0f15b5dce6a35bc21b7dc4a409ec52afb5b3074a91a507968.js\">\u003C/script>\u003Clink rel=\"stylesheet\" href=\"https://badge.dimensions.ai/badge.css\">\u003C/head>\n\u003Cbody scroll-spy=\"\" scroll-offset=\"120\">\n\t\u003Cdiv navigation-bar=\"\">\u003C!-- ngIf: $state.current.name != 'root' -->\u003Cdiv class=\"navbar navbar-default navbar-fixed-top ng-scope\" role=\"navigation\" ng-if=\"$state.current.name != 'root'\" ng-controller=\"NavbarController\">\n\t\u003Cdiv class=\"navbar-default-background\">\n\t\t\u003Cdiv class=\"navbar-header\">\n\t\t\t\u003Cbutton type=\"button\" class=\"navbar-toggle navbar-toggle-options\" ng-click=\"isCollapsed = !isCollapsed\">\n\t\t\t\t\u003Cspan class=\"sr-only\">Toggle navigation\u003C/span>\n\t\t\t\t\u003Cspan class=\"icon-bar\">\u003C/span>\n\t\t\t\t\u003Cspan class=\"icon-bar\">\u003C/span>\n\t\t\t\t\u003Cspan class=\"icon-bar\">\u003C/span>\n\t\t\t\u003C/button>\n\t\t\u003C/div>\n\t\t\u003Cdiv class=\"navbar-collapse collapse\" uib-collapse=\"!isCollapsed\" style=\"height: 0px;\">\n\t\t\t\u003Cdiv class=\"col-sm-12 col-lg-12 ng-scope\" ng-controller=\"LoginMangerController as loginCtrl\">\n\t\t\t\t\u003Cul class=\"nav navbar-nav col-sm-12\" style=\"display: flex; flex-wrap: wrap;\">\n\t\t\t\t\t\u003Cli>\n\t\t\t\t\t\t\u003Ca href=\"\" ng-click=\"homeButtonClicked()\">\n\t\t\t\t\t\t\t\u003Cimg src=\"img/biotools_white.svg\" alt=\"Responsive image\" width=\"auto\" height=\"80\" style=\"margin-left:-5px; margin-top:-22px; margin-bottom: -3000px; display: flex;\" class=\"biotools-logo\">\n\t\t\t\t\t\t\u003C/a>\n\t\t\t\t\t\u003C/li>\n\t\t\t\t\t\u003Cli class=\"navbar-button\" style=\"flex-grow: 1;\">\u003C!-- ngIf: showSearch -->\u003Cdiv search-bar=\"\" ng-if=\"showSearch\" class=\"ng-scope\">\u003Cdiv class=\"search-bar-container search-bar\" style=\"display: flex;\">\t\n\t\u003Ctags-input ng-model=\"Query.current\" style=\"flex-grow: 1; overflow: visible; width: 160px;\" placeholder=\"Search bio.tools\" template=\"components/searchBar/searchTagTemplate.html\" on-tag-added=\"tagAdded($tag); tagsChanged();\" on-tag-removed=\"tagsChanged()\" attribute-list=\"Attribute.description\" replace-spaces-with-dashes=\"false\" min-length=\"1\" class=\"ng-pristine ng-untouched ng-valid ng-isolate-scope ng-valid-max-tags ng-valid-min-tags ng-valid-leftover-text\">\u003Cdiv class=\"host\" tabindex=\"-1\" ng-click=\"eventHandlers.host.click()\" ti-transclude-append=\"\">\u003Cdiv class=\"tags\" ng-class=\"{focused: hasFocus}\">\u003Cul class=\"tag-list\">\u003C!-- ngRepeat: tag in tagList.items track by track(tag) -->\u003Cli class=\"tag-item ng-scope\" ng-repeat=\"tag in tagList.items track by track(tag)\" ng-class=\"{ selected: tag == tagList.selected }\" ng-click=\"eventHandlers.tag.click(tag)\">\u003Cti-tag-item data=\"::tag\" class=\"ng-isolate-scope\">\u003C!-- ngInclude: undefined -->\u003C/ti-tag-item>\u003C/li>\u003C!-- end ngRepeat: tag in tagList.items track by track(tag) -->\u003C/ul>\u003Cinput class=\"input ng-pristine ng-untouched ng-valid\" autocomplete=\"off\" ng-model=\"newTag.text\" ng-model-options=\"{getterSetter: true}\" ng-keydown=\"eventHandlers.input.keydown($event)\" ng-focus=\"eventHandlers.input.focus($event)\" ng-blur=\"eventHandlers.input.blur($event)\" ng-paste=\"eventHandlers.input.paste($event)\" ng-trim=\"false\" ng-class=\"{'invalid-tag': newTag.invalid}\" ng-disabled=\"disabled\" ti-bind-attrs=\"{type: options.type, placeholder: options.placeholder, tabindex: options.tabindex, spellcheck: options.spellcheck}\" ti-autosize=\"\" type=\"text\" placeholder=\"Search bio.tools\" spellcheck=\"true\" style=\"width: 163px;\">\u003Cspan class=\"input\" style=\"visibility: hidden; width: auto; white-space: pre; display: none;\">Search bio.tools\u003C/span>\u003C/div>\n\t\t\u003Cauto-complete source=\"loadSuggestions(filter.selected, $query)\" max-results-to-show=\"9\" select-first-match=\"false\" debounce-delay=\"100\" min-length=\"1\" attribute-list=\"Attribute.description\" filter=\"filter\" load-on-empty=\"false\" load-on-focus=\"true\" display-property=\"text\" class=\"ng-scope ng-isolate-scope\">\u003C!-- ngIf: suggestionList.visible -->\u003C/auto-complete>\n\t\u003C/div>\u003C/tags-input>\n\t\t\u003Cspan ng-show=\"ToolList.count &gt; 0\" class=\"search-bar-right-info-text ng-binding ng-hide\">0 tools\u003C/span>\n\u003C/div>\u003C/div>\u003C!-- end ngIf: showSearch -->\u003C/li>\n\t\t\t\t\t\n\t\t\t\t\t\u003Cli uib-dropdown=\"\" class=\"navbar-button dropdown\">\n\t\t\t\t\t\t\u003Ca href=\"\" uib-dropdown-toggle=\"\" class=\"dropdown-toggle\" aria-haspopup=\"true\" aria-expanded=\"false\">Explore \u003Cspan class=\"caret\">\u003C/span>\u003C/a>\n\t\t\t\t\t\t\u003Cul class=\"uib-dropdown-menu dropdown-menu-navbar dropdown-menu\">\n\t\t\t\t\t\t\t\u003Cli ui-sref-active=\"active\" class=\"\">\u003Ca ui-sref=\"search\" href=\"/t\">Tools\u003C/a>\u003C/li>\n\t\t\t\t\t\t\t\u003Cli ui-sref-active=\"active\" class=\"\">\u003Ca ui-sref=\"domains\" href=\"/domains\">Domains\u003C/a>\u003C/li>\n\t\t\t\t\t\t\t\u003Cli ui-sref-active=\"active\" class=\"\">\u003Ca ui-sref=\"communities\" href=\"/communities\">Communities\u003C/a>\u003C/li>\n\t\t\t\t\t\t\t\u003Cli ui-sref-active=\"active\" class=\"\">\u003Ca ui-sref=\"about\" href=\"/about\">About bio.tools\u003C/a>\u003C/li>\n\t\t\t\t\t\t\u003C/ul>\n\t\t\t\t\t\u003C/li>\n\t\t\t\t\t\n\t\t\t\t\t\u003C!-- ngIf: User.authenticated -->\n\n\t\t\t\t\t\u003C!-- ngIf: User.authenticated -->\n\n\t\t\t\t\t\u003C!-- ngIf: !User.authenticated -->\u003Cli ng-if=\"!User.authenticated\" class=\"navbar-button-bold ng-scope\">\u003Ca href=\"\" uib-dropdown-toggle=\"\" ng-click=\"loginCtrl.openLoginModal()\">Login\u003C/a>\u003C/li>\u003C!-- end ngIf: !User.authenticated -->\n\t\t\t\t\t\u003C!-- ngIf: !User.authenticated -->\u003Cli ng-if=\"!User.authenticated\" class=\"navbar-button-bold ng-scope\">\u003Ca href=\"\" uib-dropdown-toggle=\"\" ng-click=\"loginCtrl.openLoginModal()\">Sign-up\u003C/a>\u003C/li>\u003C!-- end ngIf: !User.authenticated -->\n\n\t\t\t\t\u003C/ul>\n\t\t\t\u003C/div>\n\t\t\u003C/div>\n\t\u003C/div>\n\u003C/div>\u003C!-- end ngIf: $state.current.name != 'root' -->\u003C/div>\n\t\u003Cdiv details-bar=\"\">\u003Cdiv ng-class=\"{'details-bar-container': showToolbar, 'details-bar-container-empty': !showToolbar}\" class=\"details-bar-container-empty\">\n\t\u003C!-- ngIf: showToolbar -->\n\u003C/div>\u003C/div>\n\t\u003Cdiv class=\"container-fluid\" style=\"margin-top: 20px;\">\n\t\t\u003Cdiv ng-controller=\"AlertsController\" class=\"container ng-scope\">\n\t\t\t\u003Cdiv class=\"alert-panel alert ng-isolate-scope alert-warning ng-hide\" ng-class=\"['alert-' + (type || 'warning'), closeable ? 'alert-dismissible' : null]\" role=\"alert\" ng-show=\"dev_alert\" type=\"warning\">\n    \u003Cbutton ng-show=\"closeable\" type=\"button\" class=\"close ng-hide\" ng-click=\"close({$event: $event})\">\n        \u003Cspan aria-hidden=\"true\">×\u003C/span>\n        \u003Cspan class=\"sr-only\">Close\u003C/span>\n    \u003C/button>\n    \u003Cdiv ng-transclude=\"\">\u003Cspan class=\"ng-scope\">This is a development version of the registry. There is no guarantee that the data entered here will be preserved in the future. If you want to add new tools please use the stable version avaliable at \u003C/span>\u003Ca href=\"http://bio.tools/\" target=\"_blank\" class=\"ng-scope\">bio.tools\u003C/a>\u003Cspan class=\"ng-scope\">.\u003C/span>\u003C/div>\n\u003C/div>\n\t\t\t\u003C!-- ngRepeat: alert in Alert.list -->\n\t\t\u003C/div>\n\t\t\u003C!-- uiView:  -->\u003Cdiv ui-view=\"\" class=\"ng-scope\">\u003C!-- uiView:  -->\u003Cdiv ui-view=\"\" class=\"ng-scope\">\n\t\u003Cdiv class=\"col-md-12 info-dialog-background info-dialog info-dialog-text ng-hide\" ng-show=\"notFound\" resource-not-found-dialog=\"\">We're sorry but we couldn't find what you were looking for. You can try searching for the resource you need \u003Ca ui-sref=\"search()\" href=\"/t\">here\u003C/a>.\u003C/div>\n\t\u003C!-- ngIf: !software.biotoolsID -->\u003Cdiv style=\"text-align:center\" ng-if=\"!software.biotoolsID\" class=\"ng-scope\">\n\t\t\u003Cdiv class=\"adjust\" spinner=\"\" style=\"margin:40px;\">\u003Cdiv class=\"spinner\">\u003C/div>\u003C/div>\n\t\u003C/div>\u003C!-- end ngIf: !software.biotoolsID -->\n\t\u003C!-- ngIf: software.biotoolsID -->\n\u003C/div>\n\u003C/div> \n\t\u003C/div>\n\t\u003Cdiv page-footer=\"\">\u003Cdiv class=\"col-md-12 page-footer-default\">\n    \u003Cdiv class=\"footer-container\">\n        \u003Cdiv class=\"row footer-row\">\n            \u003Cdiv class=\"footer-section\">\n                \u003Cdiv class=\"footer-head\">\n                    \u003Ch3>Docs\u003C/h3>\n                \u003C/div>\n                \u003Cdiv class=\"footer-links\">\n                    \u003Cdiv>\n                        \u003Ca href=\"https://biotools.readthedocs.io/en/latest/\" target=\"_blank\">bio.tools\u003C/a>\n                    \u003C/div>\n\n                    \u003Cdiv>\n                        \u003Ca href=\"https://biotools.readthedocs.io/en/latest/quickstart_guide.html\" target=\"_blank\">Quickstart Guide\u003C/a>\n                    \u003C/div>\n\n                    \u003Cdiv>\n                        \u003Ca href=\"https://biotools.readthedocs.io/en/latest/api_usage_guide.html\" target=\"_blank\">API Usage Guide\u003C/a>\n                    \u003C/div>\n\n                    \u003Cdiv>\n                        \u003Ca href=\"https://biotools.readthedocs.io/en/latest/api_reference.html\" target=\"_blank\">API Reference\u003C/a>\n                    \u003C/div>\n\n                    \u003Cdiv>\n                        \u003Ca href=\"https://biotools.readthedocs.io/en/latest/curators_guide.html\" target=\"_blank\">Curators Guide\u003C/a>\n                    \u003C/div>\n\n                    \u003Cdiv>\n                        \u003Ca href=\"https://biotoolsschema.readthedocs.io/en/latest/\" target=\"_blank\">biotoolsSchema\u003C/a>\n                    \u003C/div>\n\n                    \u003Cdiv>\n                        \u003Ca href=\"https://edamontologydocs.readthedocs.io/en/latest/\" target=\"_blank\">EDAM Ontology\u003C/a>\n                    \u003C/div>\n                \u003C/div>\n            \u003C/div>\n\n            \u003Cdiv class=\"footer-section\">\n                \u003Cdiv class=\"footer-head\">\n                    \u003Ch3>Support\u003C/h3>\n                \u003C/div>\n                \u003Cdiv class=\"footer-links\">\n                    \u003Cdiv>\n                        \u003Ca href=\"mailto:support-bio-tools@sdu.dk\">Email Us\u003C/a>\n                    \u003C/div>\n\n                    \u003Cdiv>\n                        \u003Ca href=\"https://github.com/bio-tools/biotoolsRegistry/issues\" target=\"_blank\">Issues\u003C/a>\n                    \u003C/div>\n\n                    \u003Cdiv>\n                        \u003Ca href=\"https://biotools.readthedocs.io/en/latest/what_is_biotools.html#getting-involved-a-quick-start-guide\" target=\"_blank\">Getting Involved\u003C/a>\n                    \u003C/div>\n\n                    \u003Cdiv>\n                        \u003Ca href=\"https://biotools.readthedocs.io/en/latest/license.html\" target=\"_blank\">Licensing\u003C/a>\n                    \u003C/div>\n                \u003C/div>\n            \u003C/div>\n\n            \u003Cdiv class=\"footer-section\">\n                \u003Cdiv class=\"footer-head\">\n                    \u003Ch3>About\u003C/h3>\n                \u003C/div>\n                \u003Cdiv class=\"footer-links\">\n                    \u003Cdiv>\n                        \u003Ca href=\"/domains\" ng-href=\"/domains\">bio.tools domains\u003C/a>\n                    \u003C/div>\n                    \u003Cdiv>\n                        \u003Ca href=\"/domains\" ng-href=\"/domains\">Communities in bio.tools\u003C/a>\n                    \u003C/div>\n                    \u003Cdiv>\n                        \u003Ca href=\"/about\" ng-href=\"/about\">About bio.tools\u003C/a>\n                    \u003C/div>\n\n                    \u003Cdiv>\n                        \u003Ca href=\"/stats\" target=\"_blank\">bio.tools stats\u003C/a>\n                    \u003C/div>\n\n                    \u003Cdiv>\n                        \u003Ca href=\"https://biotools.readthedocs.io/en/latest/contributors.html\" target=\"_blank\">Contributors\u003C/a>\n                    \u003C/div>\n                \u003C/div>\n            \u003C/div>\n\n            \u003Cdiv class=\"footer-section\">\n                \u003Cdiv class=\"footer-head\">\n                    \u003Ch3>GitHub\u003C/h3>\n                \u003C/div>\n                \u003Cdiv class=\"footer-links\">\n                    \u003Cdiv>\n                        \u003Ca href=\"https://github.com/bio-tools/biotoolsregistry/\" target=\"_blank\">bio.tools\u003C/a>\n                    \u003C/div>\n\n                    \u003Cdiv>\n                        \u003Ca href=\"https://github.com/bio-tools\" target=\"_blank\">bio.tools Organisation\u003C/a>\n                    \u003C/div>\n\n                    \u003Cdiv>\n                        \u003Ca href=\"http://github.com/bio-tools/biotoolsschema\" target=\"_blank\">biotoolsSchema\u003C/a>\n                    \u003C/div>\n\n                    \u003Cdiv>\n                        \u003Ca href=\"http://github.com/edamontology/edamontology/\" target=\"_blank\">EDAM Ontology\u003C/a>\n                    \u003C/div>\n                \u003C/div>\n            \u003C/div>\n        \u003C/div>\n        \u003Cdiv class=\"row footer-row\" style=\"text-align: center; margin-top: 20px; font-size: 1em\">\n            \u003Cp>\n                This site uses essential session cookies for user authentication and site\n                functionality. No tracking cookies are used.\n            \u003C/p>\n        \u003C/div>\n    \u003C/div>\n\u003C/div>\n\u003C/div>\n\t\u003Cscript src=\"/dist/vendor.min.js\">\u003C/script>\n\t\u003Cscript src=\"/dist/app.min.js\">\u003C/script>\n\n\t\u003Cscript type=\"text/javascript\" src=\"https://d1bxh8uas1mnw7.cloudfront.net/assets/embed.js\">\u003C/script>\n\t\u003Cscript async=\"\" src=\"https://badge.dimensions.ai/badge.js\" charset=\"utf-8\">\u003C/script>\n\n\n\u003C/body>\u003C/html>"}

# %%
print(data["value"])
# Out:
# <html lang="en" ng-app="elixir_front" class="no-js ng-scope"><!--<![endif]--><head><style type="text/css">@charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\:form{display:block;}.ng-animate-shim{visibility:hidden;}.ng-anchor{position:absolute;}</style>
# 	<meta charset="utf-8">
# 	<base href="/">
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge">
# 	<meta name="google-site-verification" content="Vk6bfzjuRdI3ej15jMi0_wW1pUoduExCekkrNpO9u2U">
# 	<title ng-bind="ngMeta.title" class="ng-binding">bio.tools</title>
# 	<meta name="description" content="">
# 	<meta property="og:title" content="">
# 	<meta property="og:description" content="">
# 	<meta property="og:image" content="https://bio.tools/img/ELIXIR_logo_white_background_small.png">
#     <meta property="datePublished" content="">
#     <meta property="article:published_time" content="">
# ...
