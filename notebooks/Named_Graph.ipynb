# %%
from rdflib import ConjunctiveGraph, URIRef, Literal, Namespace, Dataset
SCHEMA = Namespace("http://schema.org/")

#

# %%
## 1. Creating named graphs from scratch

# %%
G = ConjunctiveGraph()
G.add((URIRef("http://test1"), SCHEMA.name, Literal("name1"), URIRef("http://univ-nantes.fr/itx") ))
G.add((URIRef("http://test2"), SCHEMA.name, Literal("name2"), URIRef("http://univ-nantes.fr/itx") ))
G.add((URIRef("http://test3"), SCHEMA.name, Literal("name3"), URIRef("http://amu.fr/tagc") ))
# Out:
# <Graph identifier=N14e2ff033d2c4a0997be4c1ddb67bac2 (<class 'rdflib.graph.ConjunctiveGraph'>)>

# %%
print(G.serialize(format="trig"))
print(G.serialize(format="nquads"))
# Out:
# @prefix ns1: <http://univ-nantes.fr/> .
# @prefix ns2: <http://schema.org/> .
# @prefix ns3: <http://amu.fr/> .
#
# ns1:itx {
#     <http://test1> ns2:name "name1" .
#
#     <http://test2> ns2:name "name2" .
# }
#
# ns3:tagc {
#     <http://test3> ns2:name "name3" .
# }
#
#
# <http://test1> <http://schema.org/name> "name1" <http://univ-nantes.fr/itx> .
# <http://test2> <http://schema.org/name> "name2" <http://univ-nantes.fr/itx> .
# <http://test3> <http://schema.org/name> "name3" <http://amu.fr/tagc> .

# %%
print(G.serialize(format="turtle"))
# Out:
# @prefix ns2: <http://schema.org/> .
#
# <http://test1> ns2:name "name1" .
#
# <http://test2> ns2:name "name2" .
#
# <http://test3> ns2:name "name3" .

# %%
G2 = ConjunctiveGraph(identifier="http://univ-nantes.fr/itx")
G2.bind("sc", SCHEMA)
G2.bind("unantes", Namespace("http://univ-nantes.fr/"))
G2.add((URIRef("http://test1"), SCHEMA.name, Literal("name1")))
G2.add((URIRef("http://test2"), SCHEMA.name, Literal("name2")))

G3 = ConjunctiveGraph(identifier="http://amu/tagc")
G3.bind("amu", Namespace("http://amu/"))
G3.bind("sc", SCHEMA)
G3.add((URIRef("http://test3"), SCHEMA.name, Literal("name3")))
G3.add((URIRef("http://test4"), SCHEMA.name, Literal("name4")))
G3.add((URIRef("http://test4"), SCHEMA.identifier, Literal("id4")))

ds = Dataset()
ds.add_graph(G2)
ds.add_graph(G3)


print(ds.serialize(format="trig"))
print(ds.serialize(format="nquads"))
# Out:
# @prefix amu: <http://amu/> .
# @prefix ns1: <urn:x-rdflib:> .
# @prefix sc: <http://schema.org/> .
# @prefix unantes: <http://univ-nantes.fr/> .
#
# unantes:itx {
#     <http://test1> sc:name "name1" .
#
#     <http://test2> sc:name "name2" .
# }
#
# amu:tagc {
#     <http://test3> sc:name "name3" .
#
#     <http://test4> sc:identifier "id4" ;
#         sc:name "name4" .
# }
#
#
# <http://test1> <http://schema.org/name> "name1" <http://univ-nantes.fr/itx> .
# <http://test2> <http://schema.org/name> "name2" <http://univ-nantes.fr/itx> .
# <http://test4> <http://schema.org/name> "name4" <http://amu/tagc> .
# <http://test4> <http://schema.org/identifier> "id4" <http://amu/tagc> .
# <http://test3> <http://schema.org/name> "name3" <http://amu/tagc> .

# %%
## 2. Parsing named graphs

# %%
## 3. Querying named graphs

# %%
q1 = """
PREFIX schema: <http://schema.org/>

SELECT * WHERE {
    GRAPH ?g {
        # ?s schema:identifier ?id
    }
}
"""

# %%
res = ds.query(q1)
for r in res:
    print(f" found ID {r['id']} for resource {r['s']} originating from {r['g']}")
# Out:
#  found ID id4 for resource http://test4 originating from http://amu/tagc

# %%
q2 = """
PREFIX schema: <http://schema.org/>

SELECT * WHERE {
    GRAPH ?g {
        # ?s schema:name ?name
    }
}
"""

# %%
res = ds.query(q2)
for r in res:
    print(f" found name {r['name']} for resource {r['s']} originating from {r['g']}")
# Out:
#  found name name1 for resource http://test1 originating from http://univ-nantes.fr/itx
#  found name name2 for resource http://test2 originating from http://univ-nantes.fr/itx
#  found name name3 for resource http://test3 originating from http://amu/tagc
#  found name name4 for resource http://test4 originating from http://amu/tagc

# %%
_:N914d86f0fa364af7a5c27b85a8bfb7b3 <http://schema.org/taxonomicRange> _:Na353ce1f78624fa582ccfbfa49985b9d <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
<https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56> <http://schema.org/studySubject> _:N914d86f0fa364af7a5c27b85a8bfb7b3 <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
<https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56> <http://schema.org/identifier> "56" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:Nc81710c763ad4de69bff9814f9417868 <http://schema.org/parentTaxon> "https://www.ebi.ac.uk/ena/taxonomy/rest/scientific-name/Arabidopsis thaliana" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N5a56f5798ee840c287106e751dc9807c <http://schema.org/name> "OE-Col" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N5ba60683a8704f8ea4e50e82482dcf38 <http://schema.org/parentTaxon> "https://www.ebi.ac.uk/ena/taxonomy/rest/scientific-name/Arabidopsis thaliana" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N954cd1f7c1bf44c08907ee3c14cbf0fd <http://schema.org/name> "OE-7-1" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N40209fa6d39347debb30725dde51f769 <http://schema.org/taxonRank> "Infraspecific Rank" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N757c2461f31a4e8dafa029716154552a <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/BioChemEntity> <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N6156f44d089346c0b5d0795c2c7c11fd <http://schema.org/name> "Zm-3-1" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N01fbd4f4368946548584f14181457909 <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/BioChemEntity> <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N01fbd4f4368946548584f14181457909 <http://schema.org/name> "delta-6-9" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N6156f44d089346c0b5d0795c2c7c11fd <http://schema.org/parentTaxon> "https://www.ebi.ac.uk/ena/taxonomy/rest/scientific-name/Arabidopsis thaliana" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N54eba85dbabe4635834057ea73a6a572 <http://schema.org/name> "Zm-11-1" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:Ne491a1ee6f21433599c0e68d4b94cba7 <http://schema.org/taxonRank> "Infraspecific Rank" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
<https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56> <http://schema.org/studySubject> _:N7431825496f44d0aa5d0ba03c2f4946e <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N71d1c1bc20c3499e90adc5d6234ab949 <http://schema.org/@Type> "Taxon" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
<https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56> <http://purl.org/ppeo/PPEO.owl#hasGrowthFacility> _:N565e8ff626864d25bee15a308f92c806 <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:Ne491a1ee6f21433599c0e68d4b94cba7 <http://schema.org/name> "delta Col" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N41a8299ce60a40c8a75f33d87a8ed269 <http://schema.org/@Type> "Taxon" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:Na353ce1f78624fa582ccfbfa49985b9d <http://schema.org/taxonRank> "Infraspecific Rank" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
<https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56> <http://schema.org/name> "D4" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:
<https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N7431825496f44d0aa5d0ba03c2f4946e <http://schema.org/name> "ami-4-6" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N21f67a86396f42e4b7409fd19370dd28 <http://schema.org/name> "delta-6-9" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N0dd7b25ed3044b7e818b56cd78173096 <http://schema.org/identifier> "1303" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N43a07ad9223c4f64a9e069f294b256c9 <http://schema.org/name> "Zm Col" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N914d86f0fa364af7a5c27b85a8bfb7b3 <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/BioChemEntity> <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:Nad867c5a6c934788a0d1f95cc4f60ea1 <http://schema.org/taxonomicRange> _:N5ba60683a8704f8ea4e50e82482dcf38 <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N21f67a86396f42e4b7409fd19370dd28 <http://schema.org/parentTaxon> "https://www.ebi.ac.uk/ena/taxonomy/rest/scientific-name/Arabidopsis thaliana" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N01fbd4f4368946548584f14181457909 <http://schema.org/identifier> "1305" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N5ba60683a8704f8ea4e50e82482dcf38 <http://schema.org/name> "ami-Col" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N41a8299ce60a40c8a75f33d87a8ed269 <http://schema.org/taxonRank> "Infraspecific Rank" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
<https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56> <http://schema.org/studyProcess> "Phenotyping" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N914d86f0fa364af7a5c27b85a8bfb7b3 <http://schema.org/name> "delta-12-3" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N01fbd4f4368946548584f14181457909 <http://schema.org/taxonomicRange> _:N21f67a86396f42e4b7409fd19370dd28 <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N5a56f5798ee840c287106e751dc9807c <http://schema.org/taxonRank> "Infraspecific Rank" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N45320ac02e9f4e42b72f7a1ebb68f667 <http://schema.org/taxonRank> "Infraspecific Rank" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N70668c8a08be48a1a0fd73df7ece89b8 <http://schema.org/taxonomicRange> _:N71d1c1bc20c3499e90adc5d6234ab949 <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
<https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56> <http://schema.org/studySubject> _:N54eba85dbabe4635834057ea73a6a572 <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N954cd1f7c1bf44c08907ee3c14cbf0fd <http://schema.org/taxonomicRange> _:Nc81710c763ad4de69bff9814f9417868 <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N54eba85dbabe4635834057ea73a6a572 <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/BioChemEntity> <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
<https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56> <http://schema.org/studySubject> _:N954cd1f7c1bf44c08907ee3c14cbf0fd <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N16057cb5a30641f39835a53a9ba996b9 <http://schema.org/@Type> "Taxon" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N43a07ad9223c4f64a9e069f294b256c9 <http://schema.org/identifier> "1309" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N7431825496f44d0aa5d0ba03c2f4946e <http://schema.org/identifier> "1301" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N03bbedba2f444ef99e10e7a42da1d247 <http://schema.org/name> "OE-Col" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N03bbedba2f444ef99e10e7a42da1d247 <http://schema.org/taxonomicRange> _:N5a56f5798ee840c287106e751dc9807c <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N21f67a86396f42e4b7409fd19370dd28 <http://schema.org/taxonRank> "Infraspecific Rank" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N45320ac02e9f4e42b72f7a1ebb68f667 <http://schema.org/name> "Zm-11-1" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:Nad867c5a6c934788a0d1f95cc4f60ea1 <http://schema.org/name> "ami-Col" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N35b780b277524e8a83c0d0ec32818cb8 <http://schema.org/name> "OE-2-1" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N45320ac02e9f4e42b72f7a1ebb68f667 <http://schema.org/@Type> "Taxon" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N757c2461f31a4e8dafa029716154552a <http://schema.org/identifier> "1311" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
<https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Study> <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N70668c8a08be48a1a0fd73df7ece89b8 <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/BioChemEntity> <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N71d1c1bc20c3499e90adc5d6234ab949 <http://schema.org/parentTaxon> "https://www.ebi.ac.uk/ena/taxonomy/rest/scientific-name/Arabidopsis thaliana" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N757c2461f31a4e8dafa029716154552a <http://schema.org/name> "Zm-3-1" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
<https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56> <http://schema.org/studySubject> _:N35b780b277524e8a83c0d0ec32818cb8 <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N40209fa6d39347debb30725dde51f769 <http://schema.org/@Type> "Taxon" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:Na353ce1f78624fa582ccfbfa49985b9d <http://schema.org/name> "delta-12-3" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N71d1c1bc20c3499e90adc5d6234ab949 <http://schema.org/name> "ami-13-1" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N5a56f5798ee840c287106e751dc9807c <http://schema.org/@Type> "Taxon" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N40209fa6d39347debb30725dde51f769 <http://schema.org/name> "ami-4-6" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N565e8ff626864d25bee15a308f92c806 <http://purl.org/ppeo/PPEO.owl#hasType> "wiwam2" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N5ba60683a8704f8ea4e50e82482dcf38 <http://schema.org/taxonRank> "Infraspecific Rank" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N16057cb5a30641f39835a53a9ba996b9 <http://schema.org/name> "OE-2-1" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N7431825496f44d0aa5d0ba03c2f4946e <http://schema.org/taxonomicRange> _:N40209fa6d39347debb30725dde51f769 <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N41a8299ce60a40c8a75f33d87a8ed269 <http://schema.org/name> "Zm Col" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:Nc81710c763ad4de69bff9814f9417868 <http://schema.org/name> "OE-7-1" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N914d86f0fa364af7a5c27b85a8bfb7b3 <http://schema.org/identifier> "1304" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N0dd7b25ed3044b7e818b56cd78173096 <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/BioChemEntity> <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N21f67a86396f42e4b7409fd19370dd28 <http://schema.org/@Type> "Taxon" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N40209fa6d39347debb30725dde51f769 <http://schema.org/parentTaxon> "https://www.ebi.ac.uk/ena/taxonomy/rest/scientific-name/Arabidopsis thaliana" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N54eba85dbabe4635834057ea73a6a572 <http://schema.org/taxonomicRange> _:N45320ac02e9f4e42b72f7a1ebb68f667 <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N71d1c1bc20c3499e90adc5d6234ab949 <http://schema.org/taxonRank> "Infraspecific Rank" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N757c2461f31a4e8dafa029716154552a <http://schema.org/taxonomicRange> _:N6156f44d089346c0b5d0795c2c7c11fd <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:Ne491a1ee6f21433599c0e68d4b94cba7 <http://schema.org/parentTaxon> "https://www.ebi.ac.uk/ena/taxonomy/rest/scientific-name/Arabidopsis thaliana" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
<https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56> <http://schema.org/studySubject> _:N0dd7b25ed3044b7e818b56cd78173096 <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:Nc81710c763ad4de69bff9814f9417868 <http://schema.org/@Type> "Taxon" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N5ba60683a8704f8ea4e50e82482dcf38 <http://schema.org/@Type> "Taxon" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N70668c8a08be48a1a0fd73df7ece89b8 <http://schema.org/name> "ami-13-1" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:Na353ce1f78624fa582ccfbfa49985b9d <http://schema.org/parentTaxon> "https://www.ebi.ac.uk/ena/taxonomy/rest/scientific-name/Arabidopsis thaliana" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
_:N954cd1f7c1bf44c08907ee3c14cbf0fd <http://schema.org/identifier> "1307" <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
<https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56> <http://schema.org/endDate> "2015/09/07"^^<http://schema.org/Date> <https://pippa.psb.ugent.be/pippa_experiments/consult_experiment_basic_info/56
> .
