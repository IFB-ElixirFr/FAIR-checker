# %% [markdown]
# # Evaluation of metadata completeness with a custom profile for BioSamples
#
# This notebook shows how to use the FAIR-Checker with a **custom metadata profiles**,
# to evaluate the completeness of metadata for a set of DOIs or URLs.
#
# The metadata profile is based on the [ENA 53 checklist](https://www.ebi.ac.uk/ena/browser/view/ERC000053).
# A profile is defined as a set of mandatory, recommended and optional metadata elements.
#
# A global completeness score is computed for each evaluated metadata, based on the presence of mandatory, recommended and optional elements. A specific weight is given to each element, based on its importance for the FAIRness of the metadata.
#
# The FAIR-Checker API is better described at https://fair-checker.france-bioinformatique.fr/swagger
#
# Please report any issue at https://github.com/IFB-ElixirFr/fair-checker/issues or contact alban.gaignard@univ-nantes.fr.

# %% [markdown]
# ## Imports
#
# The cell below imports the libraries used throughout the notebook (`json`, `pandas`, `matplotlib`) and the FAIR-Checker API endpoint.

# %%
import json
import sys

import matplotlib.pyplot as plt
import pandas as pd

from notebooks.workflowhub.fetch_wfhub_fair_evals import FC_API_URL

# %% [markdown]
# # ENA checklist
#
# https://www.ebi.ac.uk/ena/browser/view/ERC000053
#
# The two cells below define the ENA 53 checklist elements grouped into mandatory, recommended and optional lists, then assemble them into a `sample_profile` targeting `schema:Sample` instances.

# %%
mandatory_elements = [
    "organism part",
    "lifestage",
    "project name",
    "collected_by",
    "collection date",
    "geographic location (region and locality)",
    "habitat",
    "sex",
    "geographic location (country and/or sea)",
    "collecting institution",
]
recommended_elements = [
    "geographic location (latitude)",
    "geographic location (longitude)",
    "specimen_voucher",
]
optional_elements = [
    "Latitude Start",
    "Longitude Start",
    "Latitude End",
    "Longitude End",
    "relationship",
    "sample symbiont of",
    "symbiont",
    "sample collection method",
    "sample coordinator affiliation",
    "sample same as",
    "sample derived from",
    "barcoding center",
    "tolid",
    "identified_by",
    "elevation",
    "identifier_affiliation",
    "original collection date",
    "original geographic location",
    "original geographic location (latitude)",
    "original geographic location (longitude)",
    "sample coordinator",
    "GAL",
    "specimen_id",
    "GAL_sample_id",
    "proxy voucher",
    "proxy biomaterial",
    "bio_material",
    "culture_or_strain_id",
    "depth",
]

# mandatory_elements = ["SRA accession", "collection_date"]
# recommended_elements = ["title", "External Id", "strain", "organism"]
# optional_elements = ["cell_type", "dev_stage", "germline"]

# %%
sample_profile = {
    "target_class": ["http://schema.org/Sample"],
    # "target_class": ["OBI:0000747"],
    "mandatory_properties": mandatory_elements,
    "recommended_properties": recommended_elements,
    "optional_properties": optional_elements,
}

# %% [markdown]
# # Generic SHACL shape for metadata completeness evaluation
#
# The cell below builds a Jinja2 template that renders a generic SHACL shape from a profile, mapping mandatory / recommended / optional elements to `sh:Violation` / `sh:Warning` / `sh:Info` constraints, and renders it for `sample_profile`.

# %%
from jinja2 import Template

shape_tpl = """
    @prefix ns: <https://fair-checker.france-bioinformatique.fr#> .
    @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
    @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
    @prefix sc: <http://schema.org/> .
    @prefix scs: <https://schema.org/> .
    @prefix bsc: <https://bioschemas.org/> .
    @prefix dct: <http://purl.org/dc/terms/> .
    @prefix sh: <http://www.w3.org/ns/shacl#> .
    @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
    @prefix edam: <http://edamontology.org/> .
    @prefix biotools: <https://bio.tools/ontology/> .

    {% for target_class in target_classes %}
    ns:test_NG_shape_{{ loop.index }}
        a sh:NodeShape ;
        sh:targetClass <{{target_class}}> ;

        {% for min_prop in min_props %}
                sh:property [
                    sh:path sc:additionalProperty ;
                    sh:qualifiedValueShape [
                        sh:property [
                            sh:path sc:name ;
                            sh:hasValue "{{min_prop}}" ;
                        ] ;

                        sh:property [
                            sh:path sc:value ;
                            sh:not [
                                sh:in ( "missing" "None" ) ;
                            ] ;
                        ] ;
                    ] ;
                    sh:qualifiedMinCount 1 ;
                    sh:severity sh:Violation ;
                ] ;
        {% endfor %}

        {% for rec_prop in rec_props %}
                sh:property [
                    sh:path sc:additionalProperty ;
                    sh:qualifiedValueShape [
                        sh:property [
                            sh:path sc:name ;
                            sh:hasValue "{{rec_prop}}" ;
                        ] ;
                        sh:property [
                            sh:path sc:value ;
                            sh:not [
                                sh:in ( "missing" "None" ) ;
                            ] ;
                        ] ;
                    ] ;

                    sh:qualifiedMinCount 1 ;
                    sh:severity sh:Warning ;
                ] ;
        {% endfor %}
        
        {% for opt_prop in opt_props %}
                sh:property [
                    sh:path sc:additionalProperty ;
                    sh:qualifiedValueShape [
                        sh:property [
                            sh:path sc:name ;
                            sh:hasValue "{{opt_prop}}" ;
                        ] ;
                        sh:property [
                            sh:path sc:value ;
                            sh:not [
                                sh:in ( "missing" "None" ) ;
                            ] ;
                        ] ;
                    ] ;
                    sh:qualifiedMinCount 1 ;
                    sh:severity sh:Info
                ] ;
        {% endfor %}
    .
    {% endfor %}
"""

template = Template(shape_tpl)

sample_shape = template.render(
    target_classes=sample_profile["target_class"],
    min_props=sample_profile["mandatory_properties"],
    rec_props=sample_profile["recommended_properties"],
    opt_props=sample_profile["optional_properties"],
)
print(sample_shape)
# Out:
#     @prefix ns: <https://fair-checker.france-bioinformatique.fr#> .
#     @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
#     @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#     @prefix sc: <http://schema.org/> .
#     @prefix scs: <https://schema.org/> .
#     @prefix bsc: <https://bioschemas.org/> .
#     @prefix dct: <http://purl.org/dc/terms/> .
#     @prefix sh: <http://www.w3.org/ns/shacl#> .
#     @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#     @prefix edam: <http://edamontology.org/> .
#     @prefix biotools: <https://bio.tools/ontology/> .
#
#
#     ns:test_NG_shape_1
#         a sh:NodeShape ;
#         sh:targetClass <http://schema.org/Sample> ;
#
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "organism part" ;
#                         ] ;
#
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Violation ;
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "lifestage" ;
#                         ] ;
#
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Violation ;
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "project name" ;
#                         ] ;
#
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Violation ;
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "collected_by" ;
#                         ] ;
#
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Violation ;
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "collection date" ;
#                         ] ;
#
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Violation ;
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "geographic location (region and locality)" ;
#                         ] ;
#
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Violation ;
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "habitat" ;
#                         ] ;
#
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Violation ;
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "sex" ;
#                         ] ;
#
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Violation ;
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "geographic location (country and/or sea)" ;
#                         ] ;
#
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Violation ;
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "collecting institution" ;
#                         ] ;
#
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Violation ;
#                 ] ;
#
#
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "geographic location (latitude)" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Warning ;
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "geographic location (longitude)" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Warning ;
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "specimen_voucher" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Warning ;
#                 ] ;
#
#
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "Latitude Start" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "Longitude Start" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "Latitude End" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "Longitude End" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "relationship" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "sample symbiont of" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "symbiont" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "sample collection method" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "sample coordinator affiliation" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "sample same as" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "sample derived from" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "barcoding center" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "tolid" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "identified_by" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "elevation" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "identifier_affiliation" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "original collection date" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "original geographic location" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "original geographic location (latitude)" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "original geographic location (longitude)" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "sample coordinator" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "GAL" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "specimen_id" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "GAL_sample_id" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "proxy voucher" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "proxy biomaterial" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "bio_material" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "culture_or_strain_id" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#                 sh:property [
#                     sh:path sc:additionalProperty ;
#                     sh:qualifiedValueShape [
#                         sh:property [
#                             sh:path sc:name ;
#                             sh:hasValue "depth" ;
#                         ] ;
#                         sh:property [
#                             sh:path sc:value ;
#                             sh:not [
#                                 sh:in ( "missing" "None" ) ;
#                             ] ;
#                         ] ;
#                     ] ;
#                     sh:qualifiedMinCount 1 ;
#                     sh:severity sh:Info
#                 ] ;
#
#     .

# %% [markdown]
# ## Evaluation of SHACL shapes
#
# The cell below defines `validate_shape()`, which runs pySHACL validation of a knowledge graph against a SHACL shape and returns the conformance flag together with the lists of infos, warnings and errors.

# %%
from rdflib import Graph, RDF
from pyshacl import validate


def validate_shape(knowledge_graph, shacl_shape):
    r = validate(
        data_graph=knowledge_graph,
        data_graph_format="turtle",
        shacl_graph=shacl_shape,
        # shacl_graph = my_shacl_constraint,
        shacl_graph_format="turtle",
        ont_graph=None,
        inference="rdfs",
        abort_on_first=False,
        meta_shacl=False,
        debug=False,
    )

    conforms, results_graph, results_text = r

    report_query = """
            SELECT ?node ?path ?path ?severity WHERE {
                # ?v rdf:type sh:ValidationReport ;
                   sh:result ?r .
                # ?r sh:focusNode ?node ;
                   sh:sourceShape ?s .
                { ?s sh:path ?path ;
                   sh:severity ?severity . }
                UNION { ?s sh:path/sh:alternativePath/rdf:rest*/rdf:first ?path ;
                   sh:severity ?severity . }
                FILTER (! isBlank(?path))
            }
        """

    results = results_graph.query(report_query)
    print("VALIDATION RESULTS")
    print(results_text)
    # print(conforms)
    # print(results_graph.serialize(format="turtle"))
    warnings = []
    errors = []
    infos = []
    for r in results:
        if "#Warning" in r["severity"]:
            # print(f'WARNING: Property {r["path"]} should be provided for {r["node"]}')
            warnings.append(f'{r["path"]}')
        if "#Violation" in r["severity"]:
            # print(f'ERROR: Property {r["path"]} must be provided for {r["node"]}')
            errors.append(f'{r["path"]}')
        if "#Info" in r["severity"]:
            # print(f'INFO: Property {r["path"]} is recommended for {r["node"]}')
            infos.append(f'{r["path"]}')

    return conforms, infos, warnings, errors

# %% [markdown]
# ## Metadata completeness evaluation based on a custom profile
#
# The cell below defines `validate_md()`, which finds the graph subjects matching the profile's target class, validates each against the rendered SHACL shape, and computes a weighted completeness score (%) from the missing mandatory / recommended / optional elements.

# %%
def validate_md(graph, profile):
    # print(f"Validating metadata with the {profile['target_class']} profile...")
    # print(f"Graph size: {len(graph)} triples")

    # print(template.render(
    #     target_classes=profile["target_class"],
    #     min_props=profile["mandatory_properties"],
    #     rec_props=profile["recommended_properties"],
    #     opt_props=profile["optional_properties"]
    # ))

    shape = template.render(
        target_classes=profile["target_class"],
        min_props=profile["mandatory_properties"],
        rec_props=profile["recommended_properties"],
        opt_props=profile["optional_properties"],
    )

    try:
        shape_kg = Graph()
        shape_kg.parse(data=shape, format="turtle")
        assert len(shape_kg) > 0
        # print(f"Shape graph size: {len(shape_kg)} triples")
        # print(shape_kg.serialize(format="turtle"))
    except Exception as e:
        print("Error parsing the SHACL shape:", e)
        print("Shape content was:")
        print(shape)
        return

    results = {}

    print()
    for s, p, o in graph.triples((None, RDF.type, None)):

        # print(f"{s.n3(graph.namespace_manager)} is a {o.n3(graph.namespace_manager)}")
        # print(f"Profile target classes: {profile['target_class']}")
        # print(str(o))

        # if o.n3(graph.namespace_manager) in profile["target_class"]:
        if str(o) in profile["target_class"]:
            print(
                f"Validating {s} (type: {o}) against profile targeting {profile['target_class']}..."
            )

            sub_kg = Graph()
            for x, y, z in graph.triples((s, None, None)):
                sub_kg.add((x, y, z))
                for x2, y2, z2 in graph.triples((z, None, None)):
                    sub_kg.add((x2, y2, z2))

            print(f"Subgraph for {s} has {len(sub_kg)} triples")
            print(sub_kg.serialize(format="turtle"))

            conforms, infos, warnings, errors = validate_shape(
                knowledge_graph=sub_kg, shacl_shape=shape
            )
            print(
                f"Validation result for {s} (type: {o}): conforms={conforms}, infos={infos}, warnings={warnings}, errors={errors}"
            )

            results[str(s)] = {
                "type": str(o),
                "ref_profile": profile["target_class"],
                "conforms": conforms,
                "infos": infos,
                "warnings": warnings,
                "errors": errors,
            }

            print(f"Validation completed for {s}.\n")
            print(json.dumps(results[str(s)], indent=2))

            n_warnings = len(results[str(s)]["warnings"])
            n_errors = len(results[str(s)]["errors"])
            n_infos = len(results[str(s)]["infos"])
            n_profile_min_props = len(profile["mandatory_properties"])
            n_profile_rec_props = len(profile["recommended_properties"])
            n_profile_opt_props = len(profile["optional_properties"])

            completeness_score = round(
                (
                        3 * (n_profile_min_props - n_errors)
                        + 2 * (n_profile_rec_props - n_warnings)
                        + 1 * (n_profile_opt_props - n_infos)
                )
                * 100
                / (
                        3 * (n_profile_min_props)
                        + 2 * (n_profile_rec_props)
                        + 1 * (n_profile_opt_props)
                ),
                2,
            )

            results[str(s)]["completeness_score"] = completeness_score

    return results

# %% [markdown]
# ## Single BioSample example
#
# The cell below defines `retrieve_rdf()`, which fetches a resource's RDF metadata via the FAIR-Checker API and loads it into an RDFLib graph, then runs the full retrieval + `validate_md()` completeness evaluation on a single BioSample.

# %%
import requests
from rdflib import Dataset


def retrieve_rdf(url):
    FC_get_md = (
        "https://fair-checker.france-bioinformatique.fr/api/inspect/get_rdf_metadata"
    )
    kg = Graph()
    res = requests.get(url=FC_get_md, params={"url": url})
    print(f"Retrieved RDF metadata from {url} with status code {res.status_code}")
    json_data = res.json()

    try:
        # The API returns JSON-LD named graphs ({"@id": ..., "@graph": [...]}).
        # Parsing those directly into a plain Graph drops every triple into a
        # named context, leaving kg empty. Parse the whole payload into a Dataset
        # and copy the quads' triples into kg instead.
        ds = Dataset()
        ds.parse(data=json.dumps(json_data), format="json-ld")
        for s, p, o, _ctx in ds.quads((None, None, None, None)):
            kg.add((s, p, o))
        print(f"Retrieved {len(kg)} RDF triples from {url}")
    except Exception as e:
        print(e)
    return kg


sample_kg = retrieve_rdf("https://www.ebi.ac.uk/biosamples/samples/SAMN33956993")

print(f"Sample graph size: {len(sample_kg)} triples")
print(sample_kg.serialize(format="turtle"))

res = validate_md(sample_kg, sample_profile)
print()
print("Validation results:")
for s, r in res.items():
    print(f"Subject: {s}")
    print(f"Type: {r['type']}")
    print(f"Conforms: {r['conforms']}")
    print(f"Completeness score: {r['completeness_score']}%")
    print()
# Out:
# Retrieved RDF metadata from https://www.ebi.ac.uk/biosamples/samples/SAMN33956993 with status code 200
# Retrieved 86 RDF triples from https://www.ebi.ac.uk/biosamples/samples/SAMN33956993
# Sample graph size: 86 triples
# @prefix ns1: <http://schema.org/> .
#
# <http://identifiers.org/biosample/SAMN33956993> a ns1:DataRecord ;
#     ns1:dateCreated "2023-03-28T19:25:04.183Z"^^ns1:Date ;
#     ns1:dateModified "2025-03-31T01:30:02.121Z"^^ns1:Date ;
#     ns1:dateReleased "2025-03-28T00:00:00Z" ;
#     ns1:dateSubmitted "2023-03-28T19:25:04.183Z" ;
#     ns1:identifier "biosample:SAMN33956993" ;
#     ns1:isPartOf <https://www.ebi.ac.uk/biosamples/samples> ;
#     ns1:mainEntity <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993> .
#
# <http://purl.obolibrary.org/obo/NCBITaxon_9606> a ns1:DefinedTerm .
#
# <https://www.ebi.ac.uk/biosamples/samples> a ns1:Dataset .
#
# <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993> a <OBI:0000747>,
#         ns1:Sample ;
#     ns1:additionalProperty [ a ns1:PropertyValue ;
#             ns1:name "geo_loc_name" ;
#             ns1:value "missing" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "INSDC center name" ;
#             ns1:value "UCSD" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "NCBI submission model" ;
#             ns1:value "Generic" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "strain" ;
#             ns1:value "Motor Neuron" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "title" ;
#             ns1:value "DDX3X-IN1" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "organism" ;
#             ns1:value "Homo sapiens" ;
#             ns1:valueReference <http://purl.obolibrary.org/obo/NCBITaxon_9606> ],
#         [ a ns1:PropertyValue ;
#             ns1:name "collection_date" ;
#             ns1:value "missing" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "INSDC status" ;
#             ns1:value "live" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "source_name" ;
#             ns1:value "Human iPSC cell lines CV-B (46, XY)" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "cell type" ;
#             ns1:value "hiPSC-derived neuron" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "SRA accession" ;
#             ns1:value "SRS17164091" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "NCBI submission package" ;
#             ns1:value "Generic.1.0" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "INSDC secondary accession" ;
#             ns1:value "SRS17164091" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "INSDC first public" ;
#             ns1:value "2025-03-28T00:00:00Z" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "INSDC last update" ;
#             ns1:value "2025-03-28T17:31:04.314Z" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "External Id" ;
#             ns1:value "SAMN33956993" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "chip antibody" ;
#             ns1:value "None" ] ;
#     ns1:identifier "biosample:SAMN33956993" ;
#     ns1:name "GSM7120767" ;
#     ns1:sameAs <http://identifiers.org/biosample/SAMN33956993> ;
#     ns1:subjectOf "https://www.ebi.ac.uk/ena/browser/view/SAMN33956993" ;
#     ns1:url <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993> .
#
#
#
# Validating https://www.ebi.ac.uk/biosamples/samples/SAMN33956993 (type: http://schema.org/Sample) against profile targeting ['http://schema.org/Sample']...
# Subgraph for https://www.ebi.ac.uk/biosamples/samples/SAMN33956993 has 84 triples
# @prefix ns1: <http://schema.org/> .
#
# <http://identifiers.org/biosample/SAMN33956993> a ns1:DataRecord ;
#     ns1:dateCreated "2023-03-28T19:25:04.183Z"^^ns1:Date ;
#     ns1:dateModified "2025-03-31T01:30:02.121Z"^^ns1:Date ;
#     ns1:dateReleased "2025-03-28T00:00:00Z" ;
#     ns1:dateSubmitted "2023-03-28T19:25:04.183Z" ;
#     ns1:identifier "biosample:SAMN33956993" ;
#     ns1:isPartOf <https://www.ebi.ac.uk/biosamples/samples> ;
#     ns1:mainEntity <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993> .
#
# <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993> a <OBI:0000747>,
#         ns1:Sample ;
#     ns1:additionalProperty [ a ns1:PropertyValue ;
#             ns1:name "geo_loc_name" ;
#             ns1:value "missing" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "INSDC center name" ;
#             ns1:value "UCSD" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "NCBI submission model" ;
#             ns1:value "Generic" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "strain" ;
#             ns1:value "Motor Neuron" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "title" ;
#             ns1:value "DDX3X-IN1" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "organism" ;
#             ns1:value "Homo sapiens" ;
#             ns1:valueReference <http://purl.obolibrary.org/obo/NCBITaxon_9606> ],
#         [ a ns1:PropertyValue ;
#             ns1:name "collection_date" ;
#             ns1:value "missing" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "INSDC status" ;
#             ns1:value "live" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "source_name" ;
#             ns1:value "Human iPSC cell lines CV-B (46, XY)" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "cell type" ;
#             ns1:value "hiPSC-derived neuron" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "SRA accession" ;
#             ns1:value "SRS17164091" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "NCBI submission package" ;
#             ns1:value "Generic.1.0" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "INSDC secondary accession" ;
#             ns1:value "SRS17164091" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "INSDC first public" ;
#             ns1:value "2025-03-28T00:00:00Z" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "INSDC last update" ;
#             ns1:value "2025-03-28T17:31:04.314Z" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "External Id" ;
#             ns1:value "SAMN33956993" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "chip antibody" ;
#             ns1:value "None" ] ;
#     ns1:identifier "biosample:SAMN33956993" ;
#     ns1:name "GSM7120767" ;
#     ns1:sameAs <http://identifiers.org/biosample/SAMN33956993> ;
#     ns1:subjectOf "https://www.ebi.ac.uk/ena/browser/view/SAMN33956993" ;
#     ns1:url <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993> .
#
#
# VALIDATION RESULTS
# Validation Report
# Conforms: False
# Results (42):
# Constraint Violation in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("collected_by") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Violation ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("collected_by") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Constraint Violation in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("collecting institution") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Violation ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("collecting institution") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Constraint Violation in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("collection date") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Violation ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("collection date") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Constraint Violation in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("geographic location (country and/or sea)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Violation ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("geographic location (country and/or sea)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Constraint Violation in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("geographic location (region and locality)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Violation ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("geographic location (region and locality)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Constraint Violation in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("habitat") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Violation ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("habitat") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Constraint Violation in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("lifestage") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Violation ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("lifestage") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Constraint Violation in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("organism part") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Violation ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("organism part") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Constraint Violation in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("project name") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Violation ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("project name") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Constraint Violation in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("sex") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Violation ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("sex") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("GAL") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("GAL") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("GAL_sample_id") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("GAL_sample_id") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("Latitude End") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("Latitude End") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("Latitude Start") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("Latitude Start") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("Longitude End") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("Longitude End") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("Longitude Start") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("Longitude Start") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("barcoding center") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("barcoding center") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("bio_material") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("bio_material") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("culture_or_strain_id") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("culture_or_strain_id") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("depth") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("depth") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("elevation") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("elevation") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("identified_by") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("identified_by") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("identifier_affiliation") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("identifier_affiliation") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("original collection date") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("original collection date") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("original geographic location (latitude)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("original geographic location (latitude)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("original geographic location (longitude)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("original geographic location (longitude)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("original geographic location") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("original geographic location") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("proxy biomaterial") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("proxy biomaterial") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("proxy voucher") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("proxy voucher") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("relationship") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("relationship") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("sample collection method") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("sample collection method") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("sample coordinator affiliation") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("sample coordinator affiliation") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("sample coordinator") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("sample coordinator") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("sample derived from") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("sample derived from") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("sample same as") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("sample same as") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("sample symbiont of") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("sample symbiont of") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("specimen_id") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("specimen_id") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("symbiont") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("symbiont") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("tolid") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("tolid") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Warning
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("geographic location (latitude)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Warning ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("geographic location (latitude)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Warning
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("geographic location (longitude)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Warning ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("geographic location (longitude)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Warning
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("specimen_voucher") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Warning ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN33956993>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("specimen_voucher") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
#
# Validation result for https://www.ebi.ac.uk/biosamples/samples/SAMN33956993 (type: http://schema.org/Sample): conforms=False, infos=['http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty'], warnings=['http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty'], errors=['http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty']
# Validation completed for https://www.ebi.ac.uk/biosamples/samples/SAMN33956993.
#
# {
#   "type": "http://schema.org/Sample",
#   "ref_profile": [
#     "http://schema.org/Sample"
#   ],
#   "conforms": false,
#   "infos": [
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty"
#   ],
#   "warnings": [
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty"
#   ],
#   "errors": [
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty"
#   ]
# }
#
# Validation results:
# Subject: https://www.ebi.ac.uk/biosamples/samples/SAMN33956993
# Type: http://schema.org/Sample
# Conforms: False
# Completeness score: 0.0%

# %% [markdown]
# ## Evaluation of a set of BioSamples
#
# The cell below iterates over a list of BioSample URLs, retrieves and validates each one with `retrieve_rdf()` and `validate_md()`, and collects their completeness scores into the `data` dictionary.

# %%
test = [
    "https://www.ebi.ac.uk/biosamples/samples/SAMN36828461",  # bad
    "https://www.ebi.ac.uk/biosamples/samples/SAMEA112797446",  # good
    "https://www.ebi.ac.uk/biosamples/samples/SAMEA115177265",
    "https://www.ebi.ac.uk/biosamples/samples/SAMEA120470990",
]

data = {}

# for doi in DOIs:
for doi in test:
    print(f"Extracting {doi} RDF metadata with FAIR-Checker...")
    sample_kg = retrieve_rdf(doi)

    if len(sample_kg) == 0:
        print(f"Failed to retrieve RDF metadata for {doi}. Skipping validation.")
        continue

    res = validate_md(sample_kg, sample_profile)
    for url in res.keys():
        print(res[url])
        data[url] = res[url]["completeness_score"]
# Out:
# Extracting https://www.ebi.ac.uk/biosamples/samples/SAMN36828461 RDF metadata with FAIR-Checker...
# Retrieved RDF metadata from https://www.ebi.ac.uk/biosamples/samples/SAMN36828461 with status code 200
# Retrieved 82 RDF triples from https://www.ebi.ac.uk/biosamples/samples/SAMN36828461
#
# Validating https://www.ebi.ac.uk/biosamples/samples/SAMN36828461 (type: http://schema.org/Sample) against profile targeting ['http://schema.org/Sample']...
# Subgraph for https://www.ebi.ac.uk/biosamples/samples/SAMN36828461 has 80 triples
# @prefix ns1: <http://schema.org/> .
#
# <http://identifiers.org/biosample/SAMN36828461> a ns1:DataRecord ;
#     ns1:dateCreated "2023-08-03T17:57:03.9Z"^^ns1:Date ;
#     ns1:dateModified "2025-03-31T01:54:29.015Z"^^ns1:Date ;
#     ns1:dateReleased "2025-03-30T00:50:15.99Z" ;
#     ns1:dateSubmitted "2023-08-03T17:57:03.9Z" ;
#     ns1:identifier "biosample:SAMN36828461" ;
#     ns1:isPartOf <https://www.ebi.ac.uk/biosamples/samples> ;
#     ns1:mainEntity <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461> .
#
# <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461> a <OBI:0000747>,
#         ns1:Sample ;
#     ns1:additionalProperty [ a ns1:PropertyValue ;
#             ns1:name "INSDC center name" ;
#             ns1:value "Taizhou University" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "INSDC first public" ;
#             ns1:value "2025-03-30T00:50:15.990Z" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "title" ;
#             ns1:value "Transcriptome sequencing of tetraploid Elsholtzia splendens leaf after cold stress" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "INSDC status" ;
#             ns1:value "live" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "INSDC secondary accession" ;
#             ns1:value "SRS18494291" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "geo_loc_name" ;
#             ns1:value "China" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "tissue" ;
#             ns1:value "leaf and flower bud replicate1" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "External Id" ;
#             ns1:value "SAMN36828461" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "collection_date" ;
#             ns1:value "2022-07-26" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "INSDC last update" ;
#             ns1:value "2025-03-30T00:50:15.990Z" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "NCBI submission package" ;
#             ns1:value "Plant.1.0" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "SRA accession" ;
#             ns1:value "SRS18494291" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "age" ;
#             ns1:value "adult" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "organism" ;
#             ns1:value "Elsholtzia splendens" ;
#             ns1:valueReference <http://purl.obolibrary.org/obo/NCBITaxon_475396> ],
#         [ a ns1:PropertyValue ;
#             ns1:name "cultivar" ;
#             ns1:value "TET-liu" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "NCBI submission model" ;
#             ns1:value "Plant" ] ;
#     ns1:identifier "biosample:SAMN36828461" ;
#     ns1:name "TLF-1" ;
#     ns1:sameAs <http://identifiers.org/biosample/SAMN36828461> ;
#     ns1:subjectOf "https://www.ebi.ac.uk/ena/browser/view/SAMN36828461" ;
#     ns1:url <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461> .
#
#
# VALIDATION RESULTS
# Validation Report
# Conforms: False
# Results (42):
# Constraint Violation in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("collected_by") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Violation ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("collected_by") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Constraint Violation in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("collecting institution") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Violation ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("collecting institution") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Constraint Violation in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("collection date") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Violation ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("collection date") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Constraint Violation in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("geographic location (country and/or sea)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Violation ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("geographic location (country and/or sea)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Constraint Violation in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("geographic location (region and locality)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Violation ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("geographic location (region and locality)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Constraint Violation in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("habitat") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Violation ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("habitat") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Constraint Violation in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("lifestage") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Violation ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("lifestage") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Constraint Violation in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("organism part") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Violation ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("organism part") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Constraint Violation in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("project name") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Violation ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("project name") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Constraint Violation in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("sex") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Violation ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("sex") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("GAL") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("GAL") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("GAL_sample_id") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("GAL_sample_id") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("Latitude End") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("Latitude End") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("Latitude Start") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("Latitude Start") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("Longitude End") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("Longitude End") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("Longitude Start") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("Longitude Start") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("barcoding center") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("barcoding center") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("bio_material") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("bio_material") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("culture_or_strain_id") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("culture_or_strain_id") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("depth") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("depth") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("elevation") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("elevation") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("identified_by") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("identified_by") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("identifier_affiliation") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("identifier_affiliation") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("original collection date") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("original collection date") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("original geographic location (latitude)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("original geographic location (latitude)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("original geographic location (longitude)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("original geographic location (longitude)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("original geographic location") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("original geographic location") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("proxy biomaterial") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("proxy biomaterial") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("proxy voucher") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("proxy voucher") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("relationship") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("relationship") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("sample collection method") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("sample collection method") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("sample coordinator affiliation") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("sample coordinator affiliation") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("sample coordinator") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("sample coordinator") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("sample derived from") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("sample derived from") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("sample same as") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("sample same as") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("sample symbiont of") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("sample symbiont of") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("specimen_id") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("specimen_id") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("symbiont") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("symbiont") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("tolid") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("tolid") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Warning
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("geographic location (latitude)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Warning ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("geographic location (latitude)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Warning
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("geographic location (longitude)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Warning ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("geographic location (longitude)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Warning
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("specimen_voucher") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Warning ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMN36828461>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("specimen_voucher") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
#
# Validation result for https://www.ebi.ac.uk/biosamples/samples/SAMN36828461 (type: http://schema.org/Sample): conforms=False, infos=['http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty'], warnings=['http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty'], errors=['http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty']
# Validation completed for https://www.ebi.ac.uk/biosamples/samples/SAMN36828461.
#
# {
#   "type": "http://schema.org/Sample",
#   "ref_profile": [
#     "http://schema.org/Sample"
#   ],
#   "conforms": false,
#   "infos": [
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty"
#   ],
#   "warnings": [
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty"
#   ],
#   "errors": [
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty"
#   ]
# }
# {'type': 'http://schema.org/Sample', 'ref_profile': ['http://schema.org/Sample'], 'conforms': False, 'infos': ['http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty'], 'warnings': ['http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty'], 'errors': ['http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty'], 'completeness_score': 0.0}
# Extracting https://www.ebi.ac.uk/biosamples/samples/SAMEA112797446 RDF metadata with FAIR-Checker...
# Retrieved RDF metadata from https://www.ebi.ac.uk/biosamples/samples/SAMEA112797446 with status code 200
# Retrieved 184 RDF triples from https://www.ebi.ac.uk/biosamples/samples/SAMEA112797446
#
# Validating https://www.ebi.ac.uk/biosamples/samples/SAMEA112797446 (type: http://schema.org/Sample) against profile targeting ['http://schema.org/Sample']...
# Subgraph for https://www.ebi.ac.uk/biosamples/samples/SAMEA112797446 has 183 triples
# @prefix ns1: <http://schema.org/> .
#
# <http://identifiers.org/biosample/SAMEA112797446> a ns1:DataRecord ;
#     ns1:dateCreated "2023-03-20T13:49:13.971Z"^^ns1:Date ;
#     ns1:dateModified "2024-12-19T13:24:51.078Z"^^ns1:Date ;
#     ns1:dateReleased "2023-03-20T13:49:14Z" ;
#     ns1:dateSubmitted "2023-03-20T13:49:14.244Z" ;
#     ns1:identifier "biosample:SAMEA112797446" ;
#     ns1:isPartOf <https://www.ebi.ac.uk/biosamples/samples> ;
#     ns1:mainEntity <https://www.ebi.ac.uk/biosamples/samples/SAMEA112797446> .
#
# <https://www.ebi.ac.uk/biosamples/samples/SAMEA112797446> a <OBI:0000747>,
#         ns1:Sample ;
#     ns1:additionalProperty [ a ns1:PropertyValue ;
#             ns1:name "geographic location (latitude)" ;
#             ns1:value "46.459337" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "collection date" ;
#             ns1:value "2022-11-08" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "original geographic location" ;
#             ns1:value "Slovenia |Pohorje | Jurgovo" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "lifestage" ;
#             ns1:value "adult" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "collector ORCID ID" ;
#             ns1:value "0000-0003-0714-5301" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "organism part" ;
#             ns1:value "SPLEEN" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "collecting institution" ;
#             ns1:value "University of Primorska" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "original collection date" ;
#             ns1:value "2022-11-08" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "habitat" ;
#             ns1:value "forest" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "specimen_id" ;
#             ns1:value "ERGA EB 5301 01" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "bio_material" ;
#             ns1:value "NOT PROVIDED" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "broker name" ;
#             ns1:value "COPO" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "sample coordinator affiliation" ;
#             ns1:value "University of Primorska" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "geographic location (region and locality)" ;
#             ns1:value "Pohorje | Jurgovo" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "Submitter Id" ;
#             ns1:value "64184ca607e169a20240e954" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "proxy voucher" ;
#             ns1:value "NOT PROVIDED" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "organism" ;
#             ns1:value "Rupicapra rupicapra" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "original geographic location (latitude)" ;
#             ns1:value "46.459337" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "sample derived from" ;
#             ns1:value "SAMEA112797440" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "sample coordinator" ;
#             ns1:value "ELENA BUZAN" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "tolid" ;
#             ns1:value "mRupRup1" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "culture_or_strain_id" ;
#             ns1:value "3" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "sample coordinator ORCID ID" ;
#             ns1:value "0000-0003-0714-5301" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "identifier_affiliation" ;
#             ns1:value "University of Primorska |University of Primorska|Faculty of Enviromental protection" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "GAL" ;
#             ns1:value "Centro Nacional de Análisis Genómico" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "geographic location (longitude)" ;
#             ns1:value "15.36074" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "project name" ;
#             ns1:value "ERGA" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "geographic location (country and/or sea)" ;
#             ns1:value "Slovenia" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "common name" ;
#             ns1:value "chamois" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "INSDC center name" ;
#             ns1:value "EarlhamInstitute" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "GAL_sample_id" ;
#             ns1:value "NOT PROVIDED" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "sex" ;
#             ns1:value "MALE" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "identified_by" ;
#             ns1:value "Aja Boncina|Elena Buzan|Bostjan Pokorny" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "title" ;
#             ns1:value "696ce13e-13d1-41c5-bbab-f13b15b7044f-erga" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "sample collection method" ;
#             ns1:value "hunted during regular hunting allocations" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "original geographic location (longitude)" ;
#             ns1:value "15.36074" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "specimen_voucher" ;
#             ns1:value "PMSL31444" ],
#         [ a ns1:PropertyValue ;
#             ns1:name "ENA-CHECKLIST" ;
# ...
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("bio_material") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMEA120470990>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("bio_material") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("culture_or_strain_id") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMEA120470990>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("culture_or_strain_id") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("depth") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMEA120470990>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("depth") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("elevation") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMEA120470990>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("elevation") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("original collection date") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMEA120470990>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("original collection date") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("original geographic location (latitude)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMEA120470990>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("original geographic location (latitude)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("original geographic location (longitude)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMEA120470990>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("original geographic location (longitude)") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("original geographic location") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMEA120470990>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("original geographic location") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("proxy biomaterial") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMEA120470990>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("proxy biomaterial") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("proxy voucher") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMEA120470990>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("proxy voucher") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("relationship") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMEA120470990>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("relationship") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("sample coordinator affiliation") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMEA120470990>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("sample coordinator affiliation") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("sample derived from") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMEA120470990>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("sample derived from") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("sample same as") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMEA120470990>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("sample same as") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("sample symbiont of") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMEA120470990>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("sample symbiont of") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
# Validation Result in QualifiedValueShapeConstraintComponent (http://www.w3.org/ns/shacl#QualifiedMinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ sh:path sc:additionalProperty ; sh:qualifiedMinCount Literal("1", datatype=xsd:integer) ; sh:qualifiedValueShape [ sh:property [ sh:hasValue Literal("tolid") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ] ; sh:severity sh:Info ]
# 	Focus Node: <https://www.ebi.ac.uk/biosamples/samples/SAMEA120470990>
# 	Result Path: sc:additionalProperty
# 	Message: Focus node does not conform to shape MinCount 1: [ sh:property [ sh:hasValue Literal("tolid") ; sh:path sc:name ], [ sh:not [ sh:in ( Literal("missing") Literal("None") ) ] ; sh:path sc:value ] ]
#
# Validation result for https://www.ebi.ac.uk/biosamples/samples/SAMEA120470990 (type: http://schema.org/Sample): conforms=False, infos=['http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty'], warnings=[], errors=[]
# Validation completed for https://www.ebi.ac.uk/biosamples/samples/SAMEA120470990.
#
# {
#   "type": "http://schema.org/Sample",
#   "ref_profile": [
#     "http://schema.org/Sample"
#   ],
#   "conforms": false,
#   "infos": [
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty",
#     "http://schema.org/additionalProperty"
#   ],
#   "warnings": [],
#   "errors": []
# }
# {'type': 'http://schema.org/Sample', 'ref_profile': ['http://schema.org/Sample'], 'conforms': False, 'infos': ['http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty', 'http://schema.org/additionalProperty'], 'warnings': [], 'errors': [], 'completeness_score': 66.15}

# %% [markdown]
# ## Results visualization

# %%
#!pip install seaborn
import seaborn as sns

# do the same with seaborn
plt.figure(figsize=(10, 6))

sns.set_theme(style="whitegrid")
sns.barplot(
    data=pd.DataFrame.from_dict(data, orient="index", columns=["completeness_score"]),
    x=data.keys(),
    hue=data.keys(),
    y="completeness_score",
    palette="viridis",
    legend=False,
)

# print the value of each bar in the center of the bar
for index, value in enumerate(data.values()):
    plt.text(index, value / 2, f"{value}%", ha="center", va="center")

plt.xlabel("URL")
plt.ylabel("Compliance Score (%)")
plt.title("Metadata Compliance Scores w.r.t the ENA 53 checklist")
plt.xticks(rotation=20, ha="right")
plt.tight_layout()
plt.show()
